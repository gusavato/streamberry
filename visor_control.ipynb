# %%
from api import *
from folder import *
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Solve Data

# %%
index = 322
solve_data(index)
films = pd.read_parquet('films.parquet')
films.loc[index,:]
# Out:
# Titulo                                                   Friend Zone
# Titulo_Original                                           Pagafantas
# Year                                                            2009
# Duracion                                                          80
# Tag_Line                             All girls want him… as a friend
# Sinopsis           Bilbao, Spain. After breaking up with Elisa, h...
# Genero                                                      [Comedy]
# TMDB_rate                                                      5.385
# Poster             https://image.tmdb.org/t/p/w400/6FDucPb45mwSeh...
# Productoras        [Telespan 2000, Sayaka Producciones Audiovisua...
# Pais                                                            [ES]
# Fecha_Estreno                                             03-07-2009
# TMDB_id                                                        20071
# IMDB_id                                                    tt1161443
# Reparto            [85557, 85558, 85559, 37559, 16975, 69529, 116...
# Director                                             [Borja Cobeaga]
# Guion                                [Borja Cobeaga, Diego San José]
# Video                    https://www.youtube.com/watch?v=ULLXgbZw_-U
# Root                                            G:\Pelis WD Elements
# Folder                                                    Pagafantas
# File               Pagafantas.(Spanish).DVD-Rip.XviD-AC3.by.Triki...
# Vista                                                           True
# Add                                                       03-10-2023
# Name: 322, dtype: object

# %%
index = 333        
TMDB_id = 1359

solve_data(index, TMDB_id)
films = pd.read_parquet('films.parquet')
films.loc[index,:]
# Out:
# Titulo                                               American Psycho
# Titulo_Original                                      American Psycho
# Year                                                            2000
# Duracion                                                         102
# Tag_Line                 I think my mask of sanity is about to slip.
# Sinopsis           A wealthy New York investment banking executiv...
# Genero                                      [Thriller, Drama, Crime]
# TMDB_rate                                                      7.401
# Poster             https://image.tmdb.org/t/p/w400/9uGHEgsiUXjCNq...
# Productoras             [Muse Productions, Pressman Film, Lionsgate]
# Pais                                                        [CA, US]
# Fecha_Estreno                                             13-04-2000
# TMDB_id                                                         1359
# IMDB_id                                                    tt0144084
# Reparto            [3894, 5293, 7499, 6164, 20767, 11154, 32029, ...
# Director                                               [Mary Harron]
# Guion                                [Mary Harron, Guinevere Turner]
# Video                    https://www.youtube.com/watch?v=5YnGhW4UEhc
# Root                                            G:\Pelis WD Elements
# Folder                                               American psycho
# File               American.Psycho.(Spanish.English).DVD-Rip.XviD...
# Vista                                                          False
# Add                                                       03-10-2023
# Name: 333, dtype: object

# %% [markdown]
# ## Explorar films

# %%
films = pd.read_parquet('films.parquet')
films.head(2)
# Out:
#                                 Titulo  \
# 0  Ninja Turtles: Fuera de las sombras
# 1     Ant-Man y la Avispa: Quantumanía
#
#                                     Titulo_Original  Year  Duracion  \
# 0  Teenage Mutant Ninja Turtles: Out of the Shadows  2016       112
# 1                 Ant-Man and the Wasp: Quantumania  2023       125
#
#                                          Tag_Line  \
# 0       Sólo un equipo puede defendernos a todos.
# 1  Sé testigo del comienzo de una nueva dinastía.
#
#                                             Sinopsis  \
# 0  Michelangelo, Donatello, Leonardo y Raphael re...
# 1  La pareja de superhéroes Scott Lang y Hope van...
#
#                                               Genero  TMDB_rate  \
# 0  [Acción, Aventura, Comedia, Familia, Ciencia f...      6.007
# 1                [Acción, Aventura, Ciencia ficción]      6.436
#
#                                               Poster  \
# 0  https://image.tmdb.org/t/p/w400/t24yGNL0aLFFfN...
# 1  https://image.tmdb.org/t/p/w400/lKHy0ntGPdQeFw...
#
#                                          Productoras  Pais Fecha_Estreno  \
# 0  [5150 Action, Paramount, Nickelodeon Movies, P...  [US]    01-06-2016
# 1          [Marvel Studios, Kevin Feige Productions]  [US]    15-02-2023
#
#    TMDB_id     IMDB_id                                            Reparto  \
# 0   308531   tt3949660  [19537, 350, 21200, 76110, 1163622, 64295, 803...
# 1   640146  tt10954600  [22226, 19034, 1674162, 221192, 1160, 3392, 74...
#
#         Director                          Guion  \
# 0   [Dave Green]  [Josh Appelbaum, André Nemec]
# 1  [Peyton Reed]                             []
#
#                                          Video      Root Folder  \
# 0  https://www.youtube.com/watch?v=Zvr3WvcYEeI  E:\Emule
# 1  https://www.youtube.com/watch?v=vbcAD04DWFE  E:\Emule
#
#                                                 File  Vista         Add
# 0  Teenage.Mutant.Ninja.Turtles.Out.of.the.Shadow...  False  26-09-2023
# 1  Ant-Man.Y.La.Avispa.(Quantumania).(Spanish.Eng...  False  26-09-2023

# %%
films.loc[332]
# Out:
# Titulo                                                          1917
# Titulo_Original                                                 1917
# Year                                                            2019
# Duracion                                                         119
# Tag_Line                                    El tiempo es el enemigo.
# Sinopsis           1917. La Gran Guerra amenazaba con cambiar, pa...
# Genero                                       [Bélica, Acción, Drama]
# TMDB_rate                                                        8.0
# Poster             https://image.tmdb.org/t/p/w400/axdhbcZeOsfX3Z...
# Productoras        [DreamWorks Pictures, Reliance Entertainment, ...
# Pais                                                [IN, ES, GB, US]
# Fecha_Estreno                                             25-12-2019
# TMDB_id                                                       530915
# IMDB_id                                                    tt8579674
# Reparto            [146750, 1332971, 2983, 125660, 512991, 238574...
# Director                                                [Sam Mendes]
# Guion                             [Sam Mendes, Krysty Wilson-Cairns]
# Video                    https://www.youtube.com/watch?v=A_N7dlgA8S4
# Root                                            G:\Pelis WD Elements
# Folder                                                     0_ULTIMAS
# File               1917.(2019).(Spanish.English.Subs).HD.1080p.x2...
# Vista                                                           True
# Add                                                       03-10-2023
# Name: 332, dtype: object

# %%
films[films.Titulo.str.contains('Nobody')]
# Out:
#                                Titulo Titulo_Original  Year  Duracion  \
# 270  Las vidas posibles de Mr. Nobody      Mr. Nobody  2009       155
# 313  Las vidas posibles de Mr. Nobody      Mr. Nobody  2009       155
#
#                            Tag_Line  \
# 270  Nada es real, todo es posible.
# 313  Nada es real, todo es posible.
#
#                                               Sinopsis  \
# 270  En el año de 2092, Nemo Nobody, un hombre de 1...
# 313  En el año de 2092, Nemo Nobody, un hombre de 1...
#
#                                           Genero  TMDB_rate  \
# 270  [Ciencia ficción, Drama, Romance, Fantasía]      7.832
# 313  [Ciencia ficción, Drama, Romance, Fantasía]      7.832
#
#                                                 Poster  \
# 270  https://image.tmdb.org/t/p/w400/dyV1SZ5tnO3FRU...
# 313  https://image.tmdb.org/t/p/w400/dyV1SZ5tnO3FRU...
#
#                                            Productoras              Pais  \
# 270  [Pan Européenne Production, Virtual Films, Wil...  [BE, CA, FR, DE]
# 313  [Pan Européenne Production, Virtual Films, Wil...  [BE, CA, FR, DE]
#
#     Fecha_Estreno  TMDB_id    IMDB_id  \
# 270    06-11-2009    31011  tt0485947
# 313    06-11-2009    31011  tt0485947
#
#                                                Reparto            Director  \
# 270  [7499, 98, 9824, 19115, 7026, 110581, 116606, ...  [Jaco Van Dormael]
# 313  [7499, 98, 9824, 19115, 7026, 110581, 116606, ...  [Jaco Van Dormael]
#
#     Guion                                        Video                  Root  \
# 270    []  https://www.youtube.com/watch?v=FnixHlYIQUc  G:\Pelis WD Elements
# 313    []  https://www.youtube.com/watch?v=FnixHlYIQUc  G:\Pelis WD Elements
#
#          Folder                                               File  Vista  \
# 270  Mr. Nobody  Mr..Nobody.(Parte.1).(Spanish.English).HDrip.X...   True
# 313  Mr. Nobody  Mr..Nobody.(Parte.2).(Spanish.English).HDrip.X...  False
#
#             Add
# 270  03-10-2023
# 313  03-10-2023

# %%
films.tail()
# Out:
#                  Titulo    Titulo_Original  Year  Duracion  \
# 261  Cuatro Fantásticos     Fantastic Four  2015       100
# 262                Dune               Dune  2021       155
# 263       Adiós pequeña      Adiós pequeña  1986        89
# 264        Nightcrawler       Nightcrawler  2014       117
# 265    Los odiosos ocho  The Hateful Eight  2015       187
#
#                                           Tag_Line  \
# 261                                  Todo cambiará
# 262         Más allá del miedo, el destino espera.
# 263
# 264           La cuidad es mas brillante de noche.
# 265  Nadie viene hasta aquí sin una maldita razón.
#
#                                               Sinopsis  \
# 261  Cuatro jóvenes inadaptados se teletransportan ...
# 262  En un lejano futuro, la galaxia conocida es go...
# 263  Beatriz es una joven y atractiva abogada que d...
# 264  Un joven descubre el mundo del periodismo free...
# 265  Seis, ocho o doce años después de la Guerra de...
#
#                                   Genero  TMDB_rate  \
# 261  [Acción, Aventura, Ciencia ficción]      4.414
# 262          [Ciencia ficción, Aventura]      7.788
# 263                           [Suspense]      0.000
# 264            [Crimen, Drama, Suspense]      7.703
# 265           [Drama, Misterio, Western]      7.747
#
#                                                 Poster  \
# 261  https://image.tmdb.org/t/p/w400/349fSE2Zd4fztR...
# 262  https://image.tmdb.org/t/p/w400/qf5bntGx2p5kQK...
# 263  https://image.tmdb.org/t/p/w400/nFu4c4sCvK00uj...
# 264  https://image.tmdb.org/t/p/w400/mP9JaSGi81tU1a...
# 265  https://image.tmdb.org/t/p/w400/7DYGdFT4gtiD5B...
#
#                                            Productoras          Pais  \
# 261  [Moving Picture Company, Marvel Entertainment,...  [GB, DE, US]
# 262                               [Legendary Pictures]          [US]
# 263                                 [Travelling Films]          [ES]
# 264                      [Sierra/Affinity, Bold Films]          [US]
# 265  [The Weinstein Company, Double Feature Films, ...          [US]
#
#     Fecha_Estreno  TMDB_id    IMDB_id  \
# 261    05-08-2015   166424  tt1502712
# 262    15-09-2021   438631  tt1160419
# 263    31-10-1986   121777  tt0090591
# 264    23-10-2014   242582  tt2872718
# 265    25-12-2015   273248  tt3460252
#
#                                                Reparto  \
# 261  [996701, 135651, 51072, 478, 20286, 38951, 146...
# 262  [1190668, 933238, 25072, 16851, 1640, 543530, ...
# 263  [227395, 21181, 15184, 36277, 30358, 34795, 78...
# 264  [131, 14343, 53240, 2053, 97604, 61084, 36060,...
# 265  [2231, 6856, 10431, 27740, 76961, 3129, 147, 6...
#
#                                            Director  \
# 261  [Stephen E. Rivkin, Simon Kinberg, Josh Trank]
# 262                              [Denis Villeneuve]
# 263                                  [Imanol Uribe]
# 264                                    [Dan Gilroy]
# 265                             [Quentin Tarantino]
#
#                                           Guion  \
# 261  [Simon Kinberg, Josh Trank, Jeremy Slater]
# 262  [Eric Roth, Denis Villeneuve, Jon Spaihts]
# 263                                          []
# 264                                          []
# 265                         [Quentin Tarantino]
#
#                                            Video                  Root  \
# 261  https://www.youtube.com/watch?v=AAgnQdiZFsQ  G:\Pelis WD Elements
# 262  https://www.youtube.com/watch?v=kPjOcWHVNGo  G:\Pelis WD Elements
# 263                                               G:\Pelis WD Elements
# 264  https://www.youtube.com/watch?v=7uaYhPpV7G4  G:\Pelis WD Elements
# 265  https://www.youtube.com/watch?v=IMGwqSA9rww  G:\Pelis WD Elements
#
#                    Folder                                               File  \
# 261    Cuatro Fantásticos  Cuatro.Fantasticos.(2015).(Spanish.English.Spa...
# 262             0_ULTIMAS  Dune.(2021).(Spanish.English.Spanishsub.Englis...
# 263  Adiós pequeña, adiós  Adios.Pequena.Adios.(Spanish.English).DVD-Rip....
# 264          Nightcrawler  Nightcrawler.(Spanish.English.spanishsub.engli...
# 265      Los Odiosos Ocho  Los.odiosos.ocho.(Spanish.English.spanishsub.e...
#
#      Vista         Add
# 261   True  03-10-2023
# 262   True  03-10-2023
# 263  False  03-10-2023
# 264  False  03-10-2023
# 265  False  03-10-2023

# %%
# films = films.drop(index=[313]).reset_index(drop=True)

# %%
films.loc[159,'Root'] = 'G:\Pelis WD Elements'
films.loc[159,'Folder'] = 'Guardianes de la galaxia'

# %%
films.to_parquet('films.parquet',engine='pyarrow')

# %% [markdown]
# ## Actualizar films

# %%
scan = pd.read_parquet('scan.parquet')
df = scan[scan.API_pass == False][:2]

save_data(df)
scan = pd.read_parquet('scan.parquet')
scan[scan.API_pass == False].head(10)
# Out:
#                                                 Titulo  Year  \
# 357                                             Esfera  1998
# 358  The Godfather_Part III [1990] BDRip 720p Dual ...  1990
# 359                                         Sin perdon
# 360                                               1941  1941
# 361                                             Nobody  2021
# 362                                    The Master 2012  2012
# 363                                          Mr Brooks
# 364                                      Love Actually
# 365                                     Red State 2011  2011
# 366                                  Pi, fe en el caos
#
#                      Root         Folder  \
# 357  G:\Pelis WD Elements      0_ULTIMAS
# 358  G:\Pelis WD Elements      0_ULTIMAS
# 359  G:\Pelis WD Elements     Sin perdon
# 360  G:\Pelis WD Elements           1941
# 361  G:\Pelis WD Elements      0_ULTIMAS
# 362  G:\Pelis WD Elements     The Master
# 363  G:\Pelis WD Elements     Mr. Brooks
# 364  G:\Pelis WD Elements  Love Actually
# 365  G:\Pelis WD Elements      Red State
# 366  G:\Pelis WD Elements             Pi
#
#                                                   File  API_pass
# 357  Esfera.(Sphere).(H.Remaster).(1998).(Spanish.E...     False
# 358  The.Godfather_Part.III.[1990].BDRip.720p.Dual....     False
# 359  Sin.perdon.(Spanish..English).DVD-Rip.XviD-AC3...     False
# 360  1941.(Spanish..English).DVD-Rip.XviD-AC3.by.vi...     False
# 361  Nobody.(2021).(Spanish.English.Subs).WEB-DL.10...     False
# 362  The.Master.2012.(Spanish.English.Subs).BDrip.7...     False
# 363  Mr.Brooks.(Spanish.English).DVD-Rip.XviD-AC3.b...     False
# 364  Love.Actually.(Spanish.English).DVD-Rip.XviD-A...     False
# 365  Red.State.2011.(Spanish.English).HDrip.XviD-AC...     False
# 366  Pi,.fe.en.el.caos.(Spanish.English).DVD-Rip.Xv...     False

# %%
insert_data(349,103332)
films = pd.read_parquet('films.parquet')
films.tail(2)
# Out:
#           Titulo Titulo_Original  Year  Duracion  \
# 342   Two Lovers      Two Lovers  2008       110
# 343  Ruby Sparks     Ruby Sparks  2012       104
#
#                                               Tag_Line  \
# 342  A veces dejamos todo para encontrarnos a nosot...
# 343                       Ella está fuera de su mente.
#
#                                               Sinopsis  \
# 342  Leonard (Joaquin Phoenix) es un joven psicológ...
# 343  Los directores de "Little Miss Sunshine" relat...
#
#                                   Genero  TMDB_rate  \
# 342                     [Drama, Romance]      6.855
# 343  [Comedia, Romance, Fantasía, Drama]      7.108
#
#                                                 Poster  \
# 342  https://image.tmdb.org/t/p/w400/u9dZ84dD12cLLe...
# 343  https://image.tmdb.org/t/p/w400/24WS7r2SOG0zJQ...
#
#                                            Productoras      Pais  \
# 342     [Tempesta Films, 2929 Productions, Wild Bunch]  [US, FR]
# 343  [Bona Fide Productions, Fox Searchlight Pictur...      [US]
#
#     Fecha_Estreno  TMDB_id    IMDB_id  \
# 342    19-11-2008    10362  tt1103275
# 343    25-07-2012   103332  tt1839492
#
#                                                Reparto  \
# 342  [73421, 12052, 5025, 6588, 562949, 13550, 1445...
# 343  [17142, 35028, 61659, 516, 3131, 61178, 212154...
#
#                              Director        Guion  \
# 342                      [James Gray]           []
# 343  [Jonathan Dayton, Valerie Faris]  [Zoe Kazan]
#
#                                            Video                  Root  \
# 342  https://www.youtube.com/watch?v=8xpmtjOsysM  G:\Pelis WD Elements
# 343  https://www.youtube.com/watch?v=6cQODwif8VY  G:\Pelis WD Elements
#
#           Folder                                               File  Vista  \
# 342   Two lovers  Two.lovers.2008.(Spanish.English).HDrip.XviD-A...  False
# 343  Ruby Sparks  Ruby.Sparks.2012.(Spanish.English).HDrip.XviD-...  False
#
#             Add
# 342  03-10-2023
# 343  03-10-2023

# %%
scan = pd.read_parquet('scan.parquet')

dictio = get_data(385687)
dictio['Root'] = scan.loc[31, 'Root']
dictio['Folder'] = scan.loc[31, 'Folder']
dictio['File'] = scan.loc[31, 'File']
dictio['Vista'] = False
dictio['Add'] = datetime.today().date().strftime('%d-%m-%Y')

pd.DataFrame([dictio])
# Out:
#              Titulo Titulo_Original  Year  Duracion  \
# 0  Fast & Furious X          Fast X  2023       142
#
#                         Tag_Line  \
# 0  El final del camino comienza.
#
#                                             Sinopsis  \
# 0  Dom Toretto y su familia se convierten en el o...
#
#                        Genero  TMDB_rate  \
# 0  [Acción, Crimen, Suspense]      7.262
#
#                                               Poster  \
# 0  https://image.tmdb.org/t/p/w400/3P9QvWVN02Etn4...
#
#                                          Productoras  Pais Fecha_Estreno  \
# 0  [Universal Pictures, Original Film, One Race, ...  [US]    17-05-2023
#
#    TMDB_id    IMDB_id                                            Reparto  \
# 0   385687  tt5433140  [12835, 17647, 8169, 8171, 56446, 1251069, 221...
#
#             Director                     Guion  \
# 0  [Louis Leterrier]  [Justin Lin, Dan Mazeau]
#
#                                          Video      Root Folder  \
# 0  https://www.youtube.com/watch?v=cg5z7wgOUig  E:\Emule
#
#                                                 File  Vista         Add
# 0  Fast.and.Furious.-.A.todo.gas.10.(2023).(Spani...  False  26-09-2023

# %% [markdown]
# ## Corrección scan

# %%
scan = pd.read_parquet('scan.parquet')
scan.head(2)
# Out:
#                                             Titulo Year      Root Folder  \
# 0  Teenage Mutant Ninja Turtles Out of the Shadows       E:\Emule
# 1                              Ant-Man Y La Avispa       E:\Emule
#
#                                                 File  API_pass
# 0  Teenage.Mutant.Ninja.Turtles.Out.of.the.Shadow...      True
# 1  Ant-Man.Y.La.Avispa.(Quantumania).(Spanish.Eng...      True

# %%
scan.loc[324,'API_pass'] = True

# %%
scan[scan.API_pass == False][:30]
# Out:
#                                                 Titulo  Year  \
# 342                                               1917  1917
# 344                                    American Psycho
# 345                                    Two lovers 2008  2008
# 346                                 Viaje a Darjeeling
# 347                                         La La Land
# 348                                  Tarde para la ira
# 349                                   Ruby Sparks 2012  2012
# 350                                Ant-Man Y La Avispa
# 351             El Caballero Oscuro  La Leyenda Renace  2012
# 352                              Nymphomaniac Volumen   2013
# 353                                        Headhunters  2011
# 354                              Una joven prometedora  2020
# 355                                         Hereditary  2018
# 356                                  El Hijo De Rambow
# 357                                             Esfera  1998
# 358  The Godfather_Part III [1990] BDRip 720p Dual ...  1990
# 359                                         Sin perdon
# 360                                               1941  1941
# 361                                             Nobody  2021
# 362                                    The Master 2012  2012
# 363                                          Mr Brooks
# 364                                      Love Actually
# 365                                     Red State 2011  2011
# 366                                  Pi, fe en el caos
# 367                              En el corazon del mar
# 368                                    28 Dias Despues  2002
# 369                                 Candidata al poder
# 370                             Algunos hombres buenos
# 371                                 El Negociador 2015  2015
# 372                                    Capitana Marvel
#
#                      Root                  Folder  \
# 342  G:\Pelis WD Elements               0_ULTIMAS
# 344  G:\Pelis WD Elements         American psycho
# 345  G:\Pelis WD Elements              Two lovers
# 346  G:\Pelis WD Elements       Viaje a Darjeling
# 347  G:\Pelis WD Elements              La La Land
# 348  G:\Pelis WD Elements       Tarde para la ira
# 349  G:\Pelis WD Elements             Ruby Sparks
# 350  G:\Pelis WD Elements     Ant Man y la avispa
# 351  G:\Pelis WD Elements   The Dark Knight Rises
# 352  G:\Pelis WD Elements   Nymphomaniac (Vol. 1)
# 353  G:\Pelis WD Elements             Headhunters
# 354  G:\Pelis WD Elements               0_ULTIMAS
# 355  G:\Pelis WD Elements              Hereditary
# 356  G:\Pelis WD Elements       El hijo de rambow
# 357  G:\Pelis WD Elements               0_ULTIMAS
# 358  G:\Pelis WD Elements               0_ULTIMAS
# 359  G:\Pelis WD Elements              Sin perdon
# 360  G:\Pelis WD Elements                    1941
# 361  G:\Pelis WD Elements               0_ULTIMAS
# 362  G:\Pelis WD Elements              The Master
# 363  G:\Pelis WD Elements              Mr. Brooks
# 364  G:\Pelis WD Elements           Love Actually
# 365  G:\Pelis WD Elements               Red State
# 366  G:\Pelis WD Elements                      Pi
# 367  G:\Pelis WD Elements   En el corazón del mar
# 368  G:\Pelis WD Elements         28 Días Después
# 369  G:\Pelis WD Elements      Candidata al Poder
# 370  G:\Pelis WD Elements  Algunos Hombres Buenos
# 371  G:\Pelis WD Elements           El Negociador
# 372  G:\Pelis WD Elements               0_ULTIMAS
#
#                                                   File  API_pass
# 342  1917.(2019).(Spanish.English.Subs).HD.1080p.x2...     False
# 344  American.Psycho.(Spanish.English).DVD-Rip.XviD...     False
# 345  Two.lovers.2008.(Spanish.English).HDrip.XviD-A...     False
# 346  Viaje.a.Darjeeling.(Spanish.English).DVD-Rip.X...     False
# 347  La.La.Land.(Spanish..English..SpanishSub..Engl...     False
# 348  Tarde.para.la.ira.(Spanish).BDrip.m1080p.x264-...     False
# 349  Ruby.Sparks.2012.(Spanish.English).HDrip.XviD-...     False
# 350  Ant-Man.Y.La.Avispa.(Spanish.English.Subs).HD....     False
# 351  El.Caballero.Oscuro..La.Leyenda.Renace.(2012)....     False
# 352  Nymphomaniac.Volumen.1(2013).(Spanish.English....     False
# 353  Headhunters.(2011).(Spanish.English..Subs).BDr...     False
# 354  Una joven prometedora (2020) [BDRip m1080p x26...     False
# 355  Hereditary.(2018).mokesky.(Spanish.English.Spa...     False
# 356  El.Hijo.De.Rambow.(Spanish.English).DVD-Rip.Xv...     False
# 357  Esfera.(Sphere).(H.Remaster).(1998).(Spanish.E...     False
# 358  The.Godfather_Part.III.[1990].BDRip.720p.Dual....     False
# 359  Sin.perdon.(Spanish..English).DVD-Rip.XviD-AC3...     False
# 360  1941.(Spanish..English).DVD-Rip.XviD-AC3.by.vi...     False
# 361  Nobody.(2021).(Spanish.English.Subs).WEB-DL.10...     False
# 362  The.Master.2012.(Spanish.English.Subs).BDrip.7...     False
# 363  Mr.Brooks.(Spanish.English).DVD-Rip.XviD-AC3.b...     False
# 364  Love.Actually.(Spanish.English).DVD-Rip.XviD-A...     False
# 365  Red.State.2011.(Spanish.English).HDrip.XviD-AC...     False
# 366  Pi,.fe.en.el.caos.(Spanish.English).DVD-Rip.Xv...     False
# 367  En.el.corazon.del.mar.(Spanish.English.spanish...     False
# 368  28.Dias.Despues.(2002).(Spanish.English).HDrip...     False
# 369  Candidata.al.poder.(Spanish.English).DVD-Rip.X...     False
# 370  Algunos.hombres.buenos.(Spanish.English).DVD-R...     False
# 371  El.Negociador.2015.(Spanish).DVD-Rip.XviD-AC3....     False
# 372  Capitana.Marvel.(Spanish.English.Subs).HD.1080...     False

# %%
# scan.to_parquet('scan.parquet', engine='pyarrow')

# %%
scan[scan.Titulo.str.contains('Futuro')]
# Out:
#                            Titulo  Year                  Root  \
# 126         Regreso Al Futuro III        G:\Pelis WD Elements
# 153  X Men Dias Del Futuro Pasado  2014  G:\Pelis WD Elements
# 184             Regreso Al Futuro        G:\Pelis WD Elements
# 435          Regreso Al Futuro II        G:\Pelis WD Elements
#
#                             Folder  \
# 126                      0_ULTIMAS
# 153  X-Men. Días del futuro pasado
# 184                      0_ULTIMAS
# 435                      0_ULTIMAS
#
#                                                   File  API_pass
# 126  Regreso.Al.Futuro.III.(Spanish.English.Subs).U...      True
# 153  X.Men.Dias.Del.Futuro.Pasado.(2014).(Spanish.E...      True
# 184  Regreso.Al.Futuro.(Spanish.English.Subs).UHD.1...      True
# 435  Regreso.Al.Futuro.II.(Spanish.English.Subs).UH...     False

# %%
scan.loc[]

# %% [markdown]
# ## Eliminar registro film

# %%
delete_film(142)
