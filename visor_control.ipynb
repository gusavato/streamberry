# %%
from api import *
from folder import *
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Solve Data

# %%
index = 422
solve_data(index)
films = pd.read_parquet('films.parquet')
films.loc[index,:]
# Out:
# Titulo                                                    About Time
# Titulo_Original                                           About Time
# Year                                                            2013
# Duracion                                                         123
# Tag_Line           What if every moment in life came with a secon...
# Sinopsis           The night after another unsatisfactory New Yea...
# Genero                                     [Drama, Romance, Fantasy]
# TMDB_rate                                                      7.905
# Poster             https://image.tmdb.org/t/p/w400/iR1bVfURbN7r1C...
# Productoras        [Working Title Films, Translux, Universal Pict...
# Pais                                                            [GB]
# Fecha_Estreno                                             04-09-2013
# TMDB_id                                                       122906
# IMDB_id                                                    tt2194499
# ...

# %%
index = 639         
TMDB_id = 86837

solve_data(index, TMDB_id)
films = pd.read_parquet('films.parquet')
films.loc[index,:]
# Out:
# Titulo                                                          Amor
# Titulo_Original                                                Amour
# Year                                                            2012
# Duracion                                                         127
# Tag_Line                                   Un film de Michael Haneke
# Sinopsis           Crudo retrato de la vejez y de la muerte. Jean...
# Genero                                              [Drama, Romance]
# TMDB_rate                                                      7.768
# Poster             https://image.tmdb.org/t/p/w400/bEFQ6P54HAC0Lr...
# Productoras        [wega film vienna, Les Films du Losange, X Fil...
# Pais                                                    [FR, AT, DE]
# Fecha_Estreno                                             20-09-2012
# TMDB_id                                                        86837
# IMDB_id                                                    tt1602620
# ...

# %% [markdown]
# ## Explorar films

# %%
films = pd.read_parquet('films.parquet')
films.head(2)
# Out:
#                                 Titulo  \
# 0  Ninja Turtles: Fuera de las sombras
# 1     Ant-Man y la Avispa: Quantumanía
#
#                                     Titulo_Original  Year  Duracion  \
# 0  Teenage Mutant Ninja Turtles: Out of the Shadows  2016       112
# 1                 Ant-Man and the Wasp: Quantumania  2023       125
#
#                                          Tag_Line  \
# 0       Sólo un equipo puede defendernos a todos.
# 1  Sé testigo del comienzo de una nueva dinastía.
#
#                                             Sinopsis  \
# 0  Michelangelo, Donatello, Leonardo y Raphael re...
# 1  La pareja de superhéroes Scott Lang y Hope van...
#
#                                               Genero  TMDB_rate  \
# 0  [Acción, Aventura, Comedia, Familia, Ciencia f...      6.007
# 1                [Acción, Aventura, Ciencia ficción]      6.436
#
#                                               Poster  \
# 0  https://image.tmdb.org/t/p/w400/t24yGNL0aLFFfN...
# ...

# %%
films.loc[332]
# Out:
# Titulo                                                          1917
# Titulo_Original                                                 1917
# Year                                                            2019
# Duracion                                                         119
# Tag_Line                                    El tiempo es el enemigo.
# Sinopsis           1917. La Gran Guerra amenazaba con cambiar, pa...
# Genero                                       [Bélica, Acción, Drama]
# TMDB_rate                                                        8.0
# Poster             https://image.tmdb.org/t/p/w400/axdhbcZeOsfX3Z...
# Productoras        [DreamWorks Pictures, Reliance Entertainment, ...
# Pais                                                [IN, ES, GB, US]
# Fecha_Estreno                                             25-12-2019
# TMDB_id                                                       530915
# IMDB_id                                                    tt8579674
# ...

# %%
films[films.Titulo.str.contains('ulio')]
# Out:
#           Titulo Titulo_Original  Year  Duracion Tag_Line  \
# 625  Julio César   Julius Caesar  1953       120
#
#                                               Sinopsis             Genero  \
# 625  Fiel adaptación para el cine de la obra homóni...  [Drama, Historia]
#
#      TMDB_rate                                             Poster  \
# 625      7.069  https://image.tmdb.org/t/p/w400/8nezcKs41dUbgF...
#
#                Productoras  Pais Fecha_Estreno  TMDB_id    IMDB_id  \
# 625  [Metro-Goldwyn-Mayer]  [US]    04-06-1953    18019  tt0045943
#
#                                                Reparto  \
# 625  [3084, 2091, 11857, 4343, 8254, 93805, 20141, ...
#
#                    Director Guion  \
# 625  [Joseph L. Mankiewicz]    []
#
#                                            Video  Root       Folder  \
# 625  https://www.youtube.com/watch?v=VpSa_AHfkDg  F:\\  Julio Cesar
#
#                                                   File  Vista         Add
# ...

# %%
films.tail()
# Out:
#                  Titulo    Titulo_Original  Year  Duracion  \
# 261  Cuatro Fantásticos     Fantastic Four  2015       100
# 262                Dune               Dune  2021       155
# 263       Adiós pequeña      Adiós pequeña  1986        89
# 264        Nightcrawler       Nightcrawler  2014       117
# 265    Los odiosos ocho  The Hateful Eight  2015       187
#
#                                           Tag_Line  \
# 261                                  Todo cambiará
# 262         Más allá del miedo, el destino espera.
# 263
# 264           La cuidad es mas brillante de noche.
# 265  Nadie viene hasta aquí sin una maldita razón.
#
#                                               Sinopsis  \
# 261  Cuatro jóvenes inadaptados se teletransportan ...
# 262  En un lejano futuro, la galaxia conocida es go...
# 263  Beatriz es una joven y atractiva abogada que d...
# 264  Un joven descubre el mundo del periodismo free...
# 265  Seis, ocho o doce años después de la Guerra de...
#
# ...

# %%
films = films.drop(index=[165]).reset_index(drop=True)

# %%
films.loc[159,'Root'] = 'G:\Pelis WD Elements'
films.loc[159,'Folder'] = 'Guardianes de la galaxia'

# %%
films.to_parquet('films.parquet',engine='pyarrow')

# %% [markdown]
# ## Actualizar films

# %%
scan = pd.read_parquet('scan.parquet')
df = scan[scan.API_pass == False][:20]

save_data(df)
scan = pd.read_parquet('scan.parquet')
scan[scan.API_pass == False].head(10)
# Out:
#                       Titulo  Year  Root  \
# 615          2010 Odisea dos  2010  F:\\
# 651          Argentina, 1985  1985  F:\\
# 658  El colapso 1x07 La isla        F:\\
# 666  La piel que habito 2011  2011  F:\\
# 667          El rey pescador        F:\\
# 668              The Visitor        F:\\
# 669                 Megamind        F:\\
# 670              Paris,Texas        F:\\
# 671                   R M N   2022  F:\\
# 672      La sombra de la ley  2018  F:\\
#
#                                                 Folder  \
# 615                                     2010. Odisea 2
# 651                                           A_NUEVAS
# 658  $RECYCLE.BINS-1-5-21-1769834031-88170737-36439...
# 666                                 La piel que habito
# 667                                    El Rey Pescador
# 668                                        The visitor
# 669                                           Megamind
# 670                                       Paris, Texas
# ...

# %%
insert_data(595,672208)
films = pd.read_parquet('films.parquet')
films.tail(2)
# Out:
#                            Titulo               Titulo_Original  Year  \
# 576  Weird: The Al Yankovic Story  Weird: The Al Yankovic Story  2022
# 577                      Un héroe                        قهرمان  2021
#
#      Duracion                         Tag_Line  \
# 576       108  The world belongs to the weird.
# 577       127
#
#                                               Sinopsis           Genero  \
# 576  Exploring every facet of ‘Weird Al’ Yankovic’s...  [Music, Comedy]
# 577  Rahim (Amir Jadidi) está en la cárcel por una ...          [Drama]
#
#      TMDB_rate                                             Poster  \
# 576      6.733  https://image.tmdb.org/t/p/w400/qcj2z13G0KjaIg...
# 577      7.402  https://image.tmdb.org/t/p/w400/8NIAwBz3vlnYeu...
#
#                                            Productoras      Pais  \
# 576  [Tango Entertainment, Funny or Die, Ear Booker...      [US]
# 577  [Amazon Studios, Memento Films Production, Mem...  [FR, IR]
#
# ...

# %%
scan = pd.read_parquet('scan.parquet')

dictio = get_data(385687)
dictio['Root'] = scan.loc[31, 'Root']
dictio['Folder'] = scan.loc[31, 'Folder']
dictio['File'] = scan.loc[31, 'File']
dictio['Vista'] = False
dictio['Add'] = datetime.today().date().strftime('%d-%m-%Y')

pd.DataFrame([dictio])
# Out:
#              Titulo Titulo_Original  Year  Duracion  \
# 0  Fast & Furious X          Fast X  2023       142
#
#                         Tag_Line  \
# 0  El final del camino comienza.
#
#                                             Sinopsis  \
# 0  Dom Toretto y su familia se convierten en el o...
#
#                        Genero  TMDB_rate  \
# 0  [Acción, Crimen, Suspense]      7.262
#
#                                               Poster  \
# 0  https://image.tmdb.org/t/p/w400/3P9QvWVN02Etn4...
#
#                                          Productoras  Pais Fecha_Estreno  \
# 0  [Universal Pictures, Original Film, One Race, ...  [US]    17-05-2023
#
#    TMDB_id    IMDB_id                                            Reparto  \
# 0   385687  tt5433140  [12835, 17647, 8169, 8171, 56446, 1251069, 221...
#
#             Director                     Guion  \
# 0  [Louis Leterrier]  [Justin Lin, Dan Mazeau]
#
#                                          Video      Root Folder  \
# ...

# %% [markdown]
# ## Corrección scan

# %%
scan = pd.read_parquet('scan.parquet')
scan.head(2)
# Out:
#                                             Titulo Year      Root Folder  \
# 0  Teenage Mutant Ninja Turtles Out of the Shadows       E:\Emule
# 1                              Ant-Man Y La Avispa       E:\Emule
#
#                                                 File  API_pass
# 0  Teenage.Mutant.Ninja.Turtles.Out.of.the.Shadow...      True
# 1  Ant-Man.Y.La.Avispa.(Quantumania).(Spanish.Eng...      True

# %%
scan.loc[[611,647],'API_pass'] = True

# %%
scan[scan.API_pass == False].head(10)
# Out:
#                     Titulo  Year  Root                      Folder  \
# 596        Paris je t'aime        F:\\             Paris Je T´aime
# 597     Despierta la furia  2021  F:\\                    A_NUEVAS
# 598  Las cenizas de Angela  1999  F:\\       Las cenizas de angela
# 599         El Caso Sloane        F:\\      A_NUEVASEl caso Sloane
# 600           Open Windows        F:\\                Open windows
# 601      Los abrazos rotos        F:\\           Los abrazos rotos
# 602                Extasis  1996  F:\\                     Extasis
# 603               Maixabel  2021  F:\\                    A_NUEVAS
# 604        El sueño eterno        F:\\             El sueño etermo
# 605    Tres Colores - Rojo        F:\\  A_NUEVASTres Colores. Rojo
#
#                                                   File  API_pass
# 596  Paris.je.t'aime.(Spanish.Catala.French).DVD-Ri...     False
# 597  Despierta.la.furia.(2021).(Spanish.English.Spa...     False
# ...

# %%
scan.to_parquet('scan.parquet', engine='pyarrow')

# %%
scan[scan.Titulo.str.contains('Julio')]
# Out:
#                         Titulo  Year      Root       Folder  \
# 61                 Julio Cesar  1953  E:\Emule
# 645                Julio Cesar  1953      F:\\  Julio Cesar
# 846  Nacido El Cuatro De Julio  1989      F:\\     A_NUEVAS
# 880                Julio Cesar  1953      F:\\  Julio Cesar
#
#                                                   File  API_pass
# 61   Julio.Cesar.(1953).(Spanish.English.Spanishsub...      True
# 645  Julio.Cesar.(1953).(Extras.V.O.S.E.).(Spanish....      True
# 846  Nacido.El.Cuatro.De.Julio.(1989).(Spanish.Engl...     False
# 880  Julio.Cesar.(1953).(Spanish.English).DVD-Rip.X...     False

# %%
scan.loc[]

# %% [markdown]
# ## Eliminar registro film

# %%
delete_film(142)

# %% [markdown]
# ## Actualizar scan

# %%
insert_scan(FOLDER[2])
