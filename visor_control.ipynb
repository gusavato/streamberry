# %%
from api import *
from folder import *
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Solve Data

# %%
index = 422
solve_data(index)
films = pd.read_parquet('films.parquet')
films.loc[index,:]
# Out:
# Titulo                                                    About Time
# Titulo_Original                                           About Time
# Year                                                            2013
# Duracion                                                         123
# Tag_Line           What if every moment in life came with a secon...
# Sinopsis           The night after another unsatisfactory New Yea...
# Genero                                     [Drama, Romance, Fantasy]
# TMDB_rate                                                      7.905
# Poster             https://image.tmdb.org/t/p/w400/iR1bVfURbN7r1C...
# Productoras        [Working Title Films, Translux, Universal Pict...
# Pais                                                            [GB]
# Fecha_Estreno                                             04-09-2013
# TMDB_id                                                       122906
# IMDB_id                                                    tt2194499
# Reparto            [93210, 53714, 2440, 1095524, 30083, 156356, 1...
# Director                                            [Richard Curtis]
# Guion                                                             []
# Video                    https://www.youtube.com/watch?v=6tHCLMVx8qY
# Root                                            G:\Pelis WD Elements
# Folder                                        Una Cuestión de Tiempo
# File               Una.cuestion.de.tiempo.(Spanish..English.Spani...
# Vista                                                           True
# Add                                                       03-10-2023
# Name: 422, dtype: object

# %%
index = 848         
TMDB_id = 653


solve_data(index, TMDB_id)
films = pd.read_parquet('films.parquet')
films.loc[index,:]
# Out:
# Titulo                                                     Nosferatu
# Titulo_Original                Nosferatu, eine Symphonie des Grauens
# Year                                                            1922
# Duracion                                                          91
# Tag_Line                         Nosferatu, una sinfonía del horror.
# Sinopsis           Año 1838. En la ciudad de Wisborg viven felice...
# Genero                                            [Fantasía, Terror]
# TMDB_rate                                                        7.7
# Poster             https://image.tmdb.org/t/p/w400/3MI2hME5h1yrGA...
# Productoras        [Prana-Film GmbH, Jofa-Atelier Berlin-Johannis...
# Pais                                                            [DE]
# Fecha_Estreno                                             16-02-1922
# TMDB_id                                                          653
# IMDB_id                                                    tt0013442
# Reparto             [9839, 9840, 9841, 9843, 9844, 9846, 9842, 9845]
# Director                                              [F. W. Murnau]
# Guion                                                [Henrik Galeen]
# Video                    https://www.youtube.com/watch?v=rg6FJfhy6GM
# Root                                                            F:\\
# Folder                                                     Nosferatu
# File               Nosferatu.(Silent).DVD-Rip.XviD-AC3.by.FitoCor...
# Vista                                                          False
# Add                                                       09-10-2023
# Name: 848, dtype: object

# %% [markdown]
# ## Explorar films

# %%
films = pd.read_parquet('films.parquet')
films.head(2)
# Out:
#                                 Titulo  \
# 0  Ninja Turtles: Fuera de las sombras
# 1     Ant-Man y la Avispa: Quantumanía
#
#                                     Titulo_Original  Year  Duracion  \
# 0  Teenage Mutant Ninja Turtles: Out of the Shadows  2016       112
# 1                 Ant-Man and the Wasp: Quantumania  2023       125
#
#                                          Tag_Line  \
# 0       Sólo un equipo puede defendernos a todos.
# 1  Sé testigo del comienzo de una nueva dinastía.
#
#                                             Sinopsis  \
# 0  Michelangelo, Donatello, Leonardo y Raphael re...
# 1  La pareja de superhéroes Scott Lang y Hope van...
#
#                                               Genero  TMDB_rate  \
# 0  [Acción, Aventura, Comedia, Familia, Ciencia f...      6.007
# 1                [Acción, Aventura, Ciencia ficción]      6.436
#
#                                               Poster  \
# 0  https://image.tmdb.org/t/p/w400/t24yGNL0aLFFfN...
# 1  https://image.tmdb.org/t/p/w400/lKHy0ntGPdQeFw...
#
#                                          Productoras  Pais Fecha_Estreno  \
# 0  [5150 Action, Paramount, Nickelodeon Movies, P...  [US]    01-06-2016
# 1          [Marvel Studios, Kevin Feige Productions]  [US]    15-02-2023
#
#    TMDB_id     IMDB_id                                            Reparto  \
# 0   308531   tt3949660  [19537, 350, 21200, 76110, 1163622, 64295, 803...
# 1   640146  tt10954600  [22226, 19034, 1674162, 221192, 1160, 3392, 74...
#
#         Director                          Guion  \
# 0   [Dave Green]  [Josh Appelbaum, André Nemec]
# 1  [Peyton Reed]                             []
#
#                                          Video      Root Folder  \
# 0  https://www.youtube.com/watch?v=Zvr3WvcYEeI  E:\Emule
# 1  https://www.youtube.com/watch?v=vbcAD04DWFE  E:\Emule
#
#                                                 File  Vista         Add
# 0  Teenage.Mutant.Ninja.Turtles.Out.of.the.Shadow...  False  26-09-2023
# 1  Ant-Man.Y.La.Avispa.(Quantumania).(Spanish.Eng...  False  26-09-2023

# %%
films.loc[[751,833],'File']
# Out:
# 751    Dublineses,.Los.muertos.(The.Dead,.1987).(Span...
# 833    Dublineses.(Los.Muertos).(H.Remaster).(1987).(...
# Name: File, dtype: object

# %%
films[films.Titulo.str.contains('The Dead')]
# Out:
#        Titulo Titulo_Original  Year  Duracion  \
# 751  The Dead        The Dead  1987        83
# 833  The Dead        The Dead  1987        83
#
#                                       Tag_Line  \
# 751  A vast, merry, and uncommon tale of love.
# 833  A vast, merry, and uncommon tale of love.
#
#                                               Sinopsis   Genero  TMDB_rate  \
# 751  After a convivial holiday dinner party, things...  [Drama]      6.955
# 833  After a convivial holiday dinner party, things...  [Drama]      6.955
#
#                                                 Poster  \
# 751  https://image.tmdb.org/t/p/w400/hFLUqiwvvtcUqA...
# 833  https://image.tmdb.org/t/p/w400/hFLUqiwvvtcUqA...
#
#                                            Productoras      Pais  \
# 751  [Delta film, Liffey Films, Vestron Pictures, Z...  [IE, GB]
# 833  [Delta film, Liffey Films, Vestron Pictures, Z...  [IE, GB]
#
#     Fecha_Estreno  TMDB_id    IMDB_id  \
# 751    03-09-1987    39507  tt0092843
# 833    03-09-1987    39507  tt0092843
#
#                                                Reparto       Director Guion  \
# 751  [5657, 87435, 6836, 79745, 150229, 150230, 168...  [John Huston]    []
# 833  [5657, 87435, 6836, 79745, 150229, 150230, 168...  [John Huston]    []
#
#                                            Video  Root  \
# 751  https://www.youtube.com/watch?v=zy6K6lViBcE  F:\\
# 833  https://www.youtube.com/watch?v=zy6K6lViBcE  F:\\
#
#                        Folder  \
# 751  Dublineses (Los Muertos)
# 833                  A_NUEVAS
#
#                                                   File  Vista         Add
# 751  Dublineses,.Los.muertos.(The.Dead,.1987).(Span...  False  09-10-2023
# 833  Dublineses.(Los.Muertos).(H.Remaster).(1987).(...  False  09-10-2023

# %%
films.tail()
# Out:
#                  Titulo    Titulo_Original  Year  Duracion  \
# 261  Cuatro Fantásticos     Fantastic Four  2015       100
# 262                Dune               Dune  2021       155
# 263       Adiós pequeña      Adiós pequeña  1986        89
# 264        Nightcrawler       Nightcrawler  2014       117
# 265    Los odiosos ocho  The Hateful Eight  2015       187
#
#                                           Tag_Line  \
# 261                                  Todo cambiará
# 262         Más allá del miedo, el destino espera.
# 263
# 264           La cuidad es mas brillante de noche.
# 265  Nadie viene hasta aquí sin una maldita razón.
#
#                                               Sinopsis  \
# 261  Cuatro jóvenes inadaptados se teletransportan ...
# 262  En un lejano futuro, la galaxia conocida es go...
# 263  Beatriz es una joven y atractiva abogada que d...
# 264  Un joven descubre el mundo del periodismo free...
# 265  Seis, ocho o doce años después de la Guerra de...
#
#                                   Genero  TMDB_rate  \
# 261  [Acción, Aventura, Ciencia ficción]      4.414
# 262          [Ciencia ficción, Aventura]      7.788
# 263                           [Suspense]      0.000
# 264            [Crimen, Drama, Suspense]      7.703
# 265           [Drama, Misterio, Western]      7.747
#
#                                                 Poster  \
# 261  https://image.tmdb.org/t/p/w400/349fSE2Zd4fztR...
# 262  https://image.tmdb.org/t/p/w400/qf5bntGx2p5kQK...
# 263  https://image.tmdb.org/t/p/w400/nFu4c4sCvK00uj...
# 264  https://image.tmdb.org/t/p/w400/mP9JaSGi81tU1a...
# 265  https://image.tmdb.org/t/p/w400/7DYGdFT4gtiD5B...
#
#                                            Productoras          Pais  \
# 261  [Moving Picture Company, Marvel Entertainment,...  [GB, DE, US]
# 262                               [Legendary Pictures]          [US]
# 263                                 [Travelling Films]          [ES]
# 264                      [Sierra/Affinity, Bold Films]          [US]
# 265  [The Weinstein Company, Double Feature Films, ...          [US]
#
#     Fecha_Estreno  TMDB_id    IMDB_id  \
# 261    05-08-2015   166424  tt1502712
# 262    15-09-2021   438631  tt1160419
# 263    31-10-1986   121777  tt0090591
# 264    23-10-2014   242582  tt2872718
# 265    25-12-2015   273248  tt3460252
#
#                                                Reparto  \
# 261  [996701, 135651, 51072, 478, 20286, 38951, 146...
# 262  [1190668, 933238, 25072, 16851, 1640, 543530, ...
# 263  [227395, 21181, 15184, 36277, 30358, 34795, 78...
# 264  [131, 14343, 53240, 2053, 97604, 61084, 36060,...
# 265  [2231, 6856, 10431, 27740, 76961, 3129, 147, 6...
#
#                                            Director  \
# 261  [Stephen E. Rivkin, Simon Kinberg, Josh Trank]
# 262                              [Denis Villeneuve]
# 263                                  [Imanol Uribe]
# 264                                    [Dan Gilroy]
# 265                             [Quentin Tarantino]
#
#                                           Guion  \
# 261  [Simon Kinberg, Josh Trank, Jeremy Slater]
# 262  [Eric Roth, Denis Villeneuve, Jon Spaihts]
# 263                                          []
# 264                                          []
# 265                         [Quentin Tarantino]
#
#                                            Video                  Root  \
# 261  https://www.youtube.com/watch?v=AAgnQdiZFsQ  G:\Pelis WD Elements
# 262  https://www.youtube.com/watch?v=kPjOcWHVNGo  G:\Pelis WD Elements
# 263                                               G:\Pelis WD Elements
# 264  https://www.youtube.com/watch?v=7uaYhPpV7G4  G:\Pelis WD Elements
# 265  https://www.youtube.com/watch?v=IMGwqSA9rww  G:\Pelis WD Elements
#
#                    Folder                                               File  \
# 261    Cuatro Fantásticos  Cuatro.Fantasticos.(2015).(Spanish.English.Spa...
# 262             0_ULTIMAS  Dune.(2021).(Spanish.English.Spanishsub.Englis...
# 263  Adiós pequeña, adiós  Adios.Pequena.Adios.(Spanish.English).DVD-Rip....
# 264          Nightcrawler  Nightcrawler.(Spanish.English.spanishsub.engli...
# 265      Los Odiosos Ocho  Los.odiosos.ocho.(Spanish.English.spanishsub.e...
#
#      Vista         Add
# 261   True  03-10-2023
# 262   True  03-10-2023
# 263  False  03-10-2023
# 264  False  03-10-2023
# 265  False  03-10-2023

# %%
films = films.drop(index=[165]).reset_index(drop=True)

# %%
films.loc[159,'Root'] = 'G:\Pelis WD Elements'
films.loc[159,'Folder'] = 'Guardianes de la galaxia'

# %%
films.to_parquet('films.parquet',engine='pyarrow')

# %% [markdown]
# ## Actualizar films

# %%
scan = pd.read_parquet('scan.parquet')
df = scan[scan.API_pass == False][:50]

save_data(df)
scan = pd.read_parquet('scan.parquet')
scan[scan.API_pass == False].head(10)
# Out:
#                       Titulo  Year  Root                            Folder  \
# 895          Melancolía 2011  2011  F:\\                          A_NUEVAS
# 907          Lazos de sangre        F:\\                   Lazos de sangre
# 918       Pleasantville 1998  1998  F:\\                     Pleasantville
# 925            Dead man 1995  1995  F:\\                          Dead Man
# 926  Mark Felt el infiltrado        F:\\  A_NUEVASMark Felt. El infiltrado
# 927      Los chicos del coro        F:\\               Los chicos del coro
# 928      Fue la mano de Dios  2021  F:\\                          A_NUEVAS
# 929                     Lamb  2021  F:\\                          A_NUEVAS
# 930    El Oficial Y El Espia        F:\\                          A_NUEVAS
# 931                    Lenny        F:\\                             Lenny
#
#                                                   File  API_pass
# 895  Melancolía.2011.(Spanish.English.French.Spanis...     False
# 907  Lazos.de.sangre.(Spanish.English.spanishsub.en...     False
# 918  Pleasantville.1998.(Spanish.English).BDrip.720...     False
# 925  Dead.man.1995.(Spanish.English).DVD-Rip.XviD-A...     False
# 926  Mark.Felt.el.infiltrado.(Spanish.English.spani...     False
# 927  Los.chicos.del.coro.(Spanish.French).HDrip.Xvi...     False
# 928  Fue.la.mano.de.Dios.(2021).(Spanish..Italian.S...     False
# 929  Lamb.(2021).(Spanish.Icelandic.Spanishsub.Engl...     False
# 930  El.Oficial.Y.El.Espia.(Spanish.French.Subs).HD...     False
# 931  Lenny.(Spanish.English).DVD-Rip.XviD-AC3.by.Tr...     False

# %%
insert_data(886,19597)
films = pd.read_parquet('films.parquet')
films.tail(2)
# Out:
#             Titulo Titulo_Original  Year  Duracion  \
# 854  Machete Kills   Machete Kills  2013       107
# 855       El erizo     Le Hérisson  2009       100
#
#                                            Tag_Line  \
# 854  Lo daban por muerto, ¡está más vivo que nunca!
# 855
#
#                                               Sinopsis  \
# 854  Tras ser contratado por el presidente de Estad...
# 855  Relato del encuentro inesperado entre algunos ...
#
#                          Genero  TMDB_rate  \
# 854  [Acción, Crimen, Suspense]      5.593
# 855            [Comedia, Drama]      7.267
#
#                                                 Poster  \
# 854  https://image.tmdb.org/t/p/w400/3i4UgSZmAJXt6E...
# 855  https://image.tmdb.org/t/p/w400/dHdIvLTurkw6iz...
#
#                                            Productoras      Pais  \
# 854  [Open Road Films, Overnight Films, AR Films, A...      [US]
# 855  [Eagle Pictures, Les Films des Tournelles, Fra...  [FR, IT]
#
#     Fecha_Estreno  TMDB_id    IMDB_id  \
# 854    12-09-2013   106747  tt2002718
# 855    01-07-2009    19597  tt1442519
#
#                                                Reparto            Director  \
# 854  [11160, 2461, 76961, 55085, 17647, 63522, 6952...  [Robert Rodriguez]
# 855  [35137, 84886, 9192, 70182, 72590, 64541, 1096...      [Mona Achache]
#
#            Guion                                        Video  Root  \
# 854  [Kyle Ward]  https://www.youtube.com/watch?v=aoiTEZWF-HQ  F:\\
# 855           []  https://www.youtube.com/watch?v=oQFTEv_41HY  F:\\
#
#             Folder                                               File  Vista  \
# 854  Machete Kills  Machete.Kills.2013.(Spanish.English).HDrip.Xvi...  False
# 855       El erizo  El.Erizo.(Le.herisson).(Spanish.French).DVD-Ri...  False
#
#             Add
# 854  09-10-2023
# 855  09-10-2023

# %%
scan = pd.read_parquet('scan.parquet')

dictio = get_data(385687)
dictio['Root'] = scan.loc[31, 'Root']
dictio['Folder'] = scan.loc[31, 'Folder']
dictio['File'] = scan.loc[31, 'File']
dictio['Vista'] = False
dictio['Add'] = datetime.today().date().strftime('%d-%m-%Y')

pd.DataFrame([dictio])
# Out:
#              Titulo Titulo_Original  Year  Duracion  \
# 0  Fast & Furious X          Fast X  2023       142
#
#                         Tag_Line  \
# 0  El final del camino comienza.
#
#                                             Sinopsis  \
# 0  Dom Toretto y su familia se convierten en el o...
#
#                        Genero  TMDB_rate  \
# 0  [Acción, Crimen, Suspense]      7.262
#
#                                               Poster  \
# 0  https://image.tmdb.org/t/p/w400/3P9QvWVN02Etn4...
#
#                                          Productoras  Pais Fecha_Estreno  \
# 0  [Universal Pictures, Original Film, One Race, ...  [US]    17-05-2023
#
#    TMDB_id    IMDB_id                                            Reparto  \
# 0   385687  tt5433140  [12835, 17647, 8169, 8171, 56446, 1251069, 221...
#
#             Director                     Guion  \
# 0  [Louis Leterrier]  [Justin Lin, Dan Mazeau]
#
#                                          Video      Root Folder  \
# 0  https://www.youtube.com/watch?v=cg5z7wgOUig  E:\Emule
#
#                                                 File  Vista         Add
# 0  Fast.and.Furious.-.A.todo.gas.10.(2023).(Spani...  False  26-09-2023

# %% [markdown]
# ## Corrección scan

# %%
scan = pd.read_parquet('scan.parquet')
scan.tail(2)
# Out:
#              Titulo Year  Root          Folder  \
# 1108       La trama       F:\\        La Trama
# 1109  Adventureland       F:\\  Adeventureland
#
#                                                    File  API_pass
# 1108  La.trama.(English.Subs).DVD-Rip.XviD-AC3.by.Ka...     False
# 1109  Adventureland.(Spanish.English).HDrip.XviD-AC3...     False

# %%
scan[scan.API_pass == False].head(10)
# Out:
#                           Titulo  Year  Root                   Folder  \
# 886                     El Erizo        F:\\                 El erizo
# 887                Domingo negro  1977  F:\\            Domingo Negro
# 888                   John Rambo  2008  F:\\               John Rambo
# 889              Lejos del cielo  2002  F:\\          Lejos del cielo
# 890                  El Rey Leon  1994  F:\\              El Rey Leon
# 891                The Gentlemen  2019  F:\\                 A_NUEVAS
# 892  Happy Thank You More Please        F:\\  HappyThankYouMorePlease
# 893                      Il divo        F:\\                 A_NUEVAS
# 894                El Compromiso  1969  F:\\            El compromiso
# 895              Melancolía 2011  2011  F:\\                 A_NUEVAS
#
#                                                   File  API_pass
# 886  El.Erizo.(Le.herisson).(Spanish.French).DVD-Ri...     False
# 887  Domingo.negro.(1977).(Spanish.English.Subs).DV...     False
# 888  John.Rambo.(2008).(Spanish.English.Subs).BDrip...     False
# 889  Lejos.del.cielo.(Far.from.heaven.2002).(Spanis...     False
# 890  El.Rey.Leon.(1994).(Spanish.English.Subs).HD.1...     False
# 891  The.Gentlemen.(2019).(Spanish.English.Subs).HD...     False
# 892  Happy.Thank.You.More.Please.(Spanish.English)....     False
# 893  Il.divo.(Spanish..Italian).DVD-Rip.XviD-AC3-mp...     False
# 894  El.Compromiso.(1969).(English.Spanish).DVD-Rip...     False
# 895  Melancolía.2011.(Spanish.English.French.Spanis...     False

# %%
scan[scan.Titulo.str.contains('Cruce')]
# Out:
#                 Titulo  Year  Root            Folder  \
# 831   Cruce de caminos        F:\\  Cruce de caminos
# 1056  Cruce de Caminos  2012  F:\\  Cruce de caminos
#
#                                                    File  API_pass
# 831   Cruce.de.caminos.(English.Spanishsub.Englishsu...      True
# 1056  Cruce.de.Caminos.(2012).(Spanish.English.Subs)...     False

# %%
scan.loc[[883],'API_pass'] = True

# %%
scan.loc[646]
# Out:
# Titulo                                        La conspiracion
# Year
# Root                                                     F:\\
# Folder                                        La Conspiración
# File        La.conspiracion.(Spanish.English).HDrip.XviD-A...
# API_pass                                                 True
# Name: 646, dtype: object

# %%
scan.to_parquet('scan.parquet', engine='pyarrow')

# %%
scan.loc[]

# %% [markdown]
# ## Eliminar registro film

# %%
delete_film(751)

# %% [markdown]
# ## Actualizar scan

# %%
insert_scan(FOLDER[2])
