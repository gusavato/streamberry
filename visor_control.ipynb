# %%
from api import *
from folder import *
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Solve Data

# %%
index = 50
solve_data(index)
films = pd.read_parquet('films.parquet')
films.loc[index,:]
# Out:
# Titulo                                              Cairo Conspiracy
# Titulo_Original                                         ولد من الجنة
# Year                                                            2022
# Duracion                                                         121
# Tag_Line
# Sinopsis           A fisherman's son is offered the ultimate priv...
# Genero                                             [Thriller, Drama]
# TMDB_rate                                                        6.8
# Poster             https://image.tmdb.org/t/p/w400/dXGNABIoMWo8EO...
# Productoras        [Atmo Production, Memento Films Production, Bu...
# Pais                                                [DK, FI, FR, SE]
# Fecha_Estreno                                             26-10-2022
# TMDB_id                                                       788977
# IMDB_id                                                   tt15452062
# Reparto            [1260004, 57012, 24289, 52685, 146358, 3711493...
# Director                                               [Tarik Saleh]
# Guion                                                             []
# Video                    https://www.youtube.com/watch?v=xjsIuA21P1Q
# Root                                                        E:\Emule
# Folder
# File               Conspiración.en.El.Cairo.(2022).(Spanish.Arabi...
# Vista                                                          False
# Add                                                       26-09-2023
# Name: 50, dtype: object

# %%
index = 175          
TMDB_id = 381283


solve_data(index, TMDB_id)
films = pd.read_parquet('films.parquet')
films.loc[index,:]
# Out:
# Titulo                                                        Madre!
# Titulo_Original                                              mother!
# Year                                                            2017
# Duracion                                                         121
# Tag_Line                                               Ver es creer.
# Sinopsis           A una mujer (Jennifer Lawrence) le pilla por s...
# Genero                                     [Drama, Suspense, Terror]
# TMDB_rate                                                      6.975
# Poster             https://image.tmdb.org/t/p/w400/bKqXhnc9gCF3Zp...
# Productoras                           [Protozoa Pictures, Paramount]
# Pais                                                            [US]
# Fecha_Estreno                                             13-09-2017
# TMDB_id                                                       381283
# IMDB_id                                                    tt5109784
# Reparto            [72129, 3810, 228, 1160, 63364, 93210, 1607522...
# Director                                          [Darren Aronofsky]
# Guion                                                             []
# Video                    https://www.youtube.com/watch?v=ovlXbhogrTc
# Root                                            G:\Pelis WD Elements
# Folder                                                         Madre
# File               Madre.(Spanish.English..Subs).HD.1080p.x264-AC...
# Vista                                                          False
# Add                                                       27-09-2023
# Name: 175, dtype: object

# %% [markdown]
# ## Explorar films

# %%
films = pd.read_parquet('films.parquet')
films.head(2)
# Out:
#                                 Titulo  \
# 0  Ninja Turtles: Fuera de las sombras
# 1     Ant-Man y la Avispa: Quantumanía
#
#                                     Titulo_Original  Year  Duracion  \
# 0  Teenage Mutant Ninja Turtles: Out of the Shadows  2016       112
# 1                 Ant-Man and the Wasp: Quantumania  2023       125
#
#                                          Tag_Line  \
# 0       Sólo un equipo puede defendernos a todos.
# 1  Sé testigo del comienzo de una nueva dinastía.
#
#                                             Sinopsis  \
# 0  Michelangelo, Donatello, Leonardo y Raphael re...
# 1  La pareja de superhéroes Scott Lang y Hope van...
#
#                                               Genero  TMDB_rate  \
# 0  [Acción, Aventura, Comedia, Familia, Ciencia f...      6.007
# 1                [Acción, Aventura, Ciencia ficción]      6.436
#
#                                               Poster  \
# 0  https://image.tmdb.org/t/p/w400/t24yGNL0aLFFfN...
# 1  https://image.tmdb.org/t/p/w400/lKHy0ntGPdQeFw...
#
#                                          Productoras  Pais Fecha_Estreno  \
# 0  [5150 Action, Paramount, Nickelodeon Movies, P...  [US]    01-06-2016
# 1          [Marvel Studios, Kevin Feige Productions]  [US]    15-02-2023
#
#    TMDB_id     IMDB_id                                            Reparto  \
# 0   308531   tt3949660  [19537, 350, 21200, 76110, 1163622, 64295, 803...
# 1   640146  tt10954600  [22226, 19034, 1674162, 221192, 1160, 3392, 74...
#
#         Director                          Guion  \
# 0   [Dave Green]  [Josh Appelbaum, André Nemec]
# 1  [Peyton Reed]                             []
#
#                                          Video      Root Folder  \
# 0  https://www.youtube.com/watch?v=Zvr3WvcYEeI  E:\Emule
# 1  https://www.youtube.com/watch?v=vbcAD04DWFE  E:\Emule
#
#                                                 File  Vista         Add
# 0  Teenage.Mutant.Ninja.Turtles.Out.of.the.Shadow...  False  26-09-2023
# 1  Ant-Man.Y.La.Avispa.(Quantumania).(Spanish.Eng...  False  26-09-2023

# %%
films.loc[13,'Root']
# Out:
# 'E:\\Emule'

# %%
films.loc[134,'Root'] = 'G:\Pelis WD Elements'
films.loc[134,'Folder'] = 'Millenium. Los hombres que no amaban a las mujeres'

# %%
films[films.Root.isna()]
# Out:
# Empty DataFrame
# Columns: [Titulo, Titulo_Original, Year, Duracion, Tag_Line, Sinopsis, Genero, TMDB_rate, Poster, Productoras, Pais, Fecha_Estreno, TMDB_id, IMDB_id, Reparto, Director, Guion, Video, Root, Folder, File, Vista, Add]
# Index: []

# %%
films[films.Titulo.str.contains('César')]
# Out:
#                Titulo     Titulo_Original  Year  Duracion  \
# 59        Julio César       Julius Caesar  1953       120
# 623       Julio César       Julius Caesar  1953       120
# 677  César debe morir  Cesare deve morire  2012        76
# 791      ¡Ave, César!       Hail, Caesar!  2016       106
#
#                       Tag_Line  \
# 59
# 623
# 677
# 791  Luces. Cámara. Secuestro.
#
#                                               Sinopsis  \
# 59   Fiel adaptación para el cine de la obra homóni...
# 623  Fiel adaptación para el cine de la obra homóni...
# 677  Los presos de la cárcel Rebibbia, en Roma, van...
# 791  En el Hollywood de los años 50, uno de los gra...
#
#                           Genero  TMDB_rate  \
# 59             [Drama, Historia]      7.069
# 623            [Drama, Historia]      7.069
# 677          [Drama, Documental]      7.300
# 791  [Comedia, Crimen, Misterio]      5.913
#
#                                                 Poster  \
# 59   https://image.tmdb.org/t/p/w400/8nezcKs41dUbgF...
# 623  https://image.tmdb.org/t/p/w400/8nezcKs41dUbgF...
# 677  https://image.tmdb.org/t/p/w400/5C8hxmO1S49qFT...
# 791  https://image.tmdb.org/t/p/w400/9QDj2tC73O2oOJ...
#
#                                            Productoras  Pais Fecha_Estreno  \
# 59                               [Metro-Goldwyn-Mayer]  [US]    04-06-1953
# 623                              [Metro-Goldwyn-Mayer]  [US]    04-06-1953
# 677                             [Kaos Cinematografica]  [IT]    11-02-2012
# 791  [Universal Pictures, Mike Zoss Productions, Wo...  [US]    05-02-2016
#
#      TMDB_id    IMDB_id                                            Reparto  \
# 59     18019  tt0045943  [3084, 2091, 11857, 4343, 8254, 93805, 20141, ...
# 623    18019  tt0045943  [3084, 2091, 11857, 4343, 8254, 93805, 20141, ...
# 677    96821  tt2177511  [1073846, 1073845, 72781, 1073847, 1073848, 10...
# 791   270487  tt0475290  [16851, 1461, 71375, 5469, 1245, 3063, 38673, ...
#
#                               Director            Guion  \
# 59              [Joseph L. Mankiewicz]               []
# 623             [Joseph L. Mankiewicz]               []
# 677  [Paolo Taviani, Vittorio Taviani]  [Paolo Taviani]
# 791            [Joel Coen, Ethan Coen]               []
#
#                                            Video      Root            Folder  \
# 59   https://www.youtube.com/watch?v=VpSa_AHfkDg  E:\Emule
# 623  https://www.youtube.com/watch?v=VpSa_AHfkDg      F:\\       Julio Cesar
# 677  https://www.youtube.com/watch?v=rQXsLENIJvQ      F:\\  Cesar Debe Morir
# 791  https://www.youtube.com/watch?v=MDffcfwsfto      F:\\         Ave Cesar
#
#                                                   File  Vista         Add
# 59   Julio.Cesar.(1953).(Spanish.English.Spanishsub...  False  26-09-2023
# 623  Julio.Cesar.(1953).(Extras.V.O.S.E.).(Spanish....  False  04-10-2023
# 677  Cesar.debe.morir.(Spanish..Italian).DVD-Rip.Xv...  False  09-10-2023
# 791  .Ave,.Cesar..(Spanish.English.spanishsub.engli...  False  09-10-2023

# %%
films[films.Titulo.duplicated()]
# Out:
#                                            Titulo  \
# 251                                       RoboCop
# 378  Doctor Strange en el multiverso de la locura
# 436                   Blackhat: Amenaza en la red
# 446                                   Jojo Rabbit
# 655                                         Madre
# 713                                       La caza
# 727                             Mi nombre es Khan
# 786                             Midnight in Paris
# 835                                   Summer 1993
# 882                          La noche del cazador
# 938                         El cielo sobre Berlín
# 952                                   El irlandés
#
#                                  Titulo_Original  Year  Duracion  \
# 251                                      RoboCop  2014       113
# 378  Doctor Strange in the Multiverse of Madness  2022       126
# 436                                     Blackhat  2015       133
# 446                                  Jojo Rabbit  2019       108
# 655                                        Madre  2019       129
# 713                                     The Hunt  2020        90
# 727                              My Name Is Khan  2010       165
# 786                            Midnight in Paris  2011        99
# 835                                   Estiu 1993  2017        96
# 882                      The Night of the Hunter  1955        93
# 938                       Der Himmel über Berlin  1987       128
# 952                                    The Guard  2011        96
#
#                                               Tag_Line  \
# 251                  El crimen tiene un nuevo enemigo.
# 378           Entra en una nueva dimensión de Strange.
# 436
# 446                         Una sátira contra el odio.
# 655
# 713        Cazar hombres es la experiencia definitiva.
# 727  Un Hombre Ordinario, Un Viaje Extraordinario.....
# 786                             Un Film de Woody Allen
# 835                         A new family. A new world.
# 882  La noche de bodas, la anticipación, el beso, e...
# 938               Hay ángeles en las calles de Berlín.
# 952
#
#                                               Sinopsis  \
# 251  La película comienza con la trágica muerte del...
# 378  Viaja a lo desconocido con el Doctor Strange, ...
# 436  Thriller cibernético en el que varios agentes ...
# 446  Jojo Rabbit es un niño viviendo en plena 2ª Gu...
# 655  Elena perdió a su hijo Iván, de seis años, en ...
# 713  Doce extraños se despiertan en el claro de un ...
# 727  Rizwan Khan (Tanay Chheda) es un niño musulmán...
# 786  Un escritor norteamericano algo bohemio llega ...
# 835  After her mother's death, six-year-old Frida i...
# 882  Tras realizar un atraco en el que han muerto d...
# 938  Dos ángeles sobrevuelan Berlín, ciudad dividid...
# 952  Gerry Boyle es un excéntrico, grosero y subver...
#
#                                           Genero  TMDB_rate  \
# 251  [Ciencia ficción, Acción, Crimen, Suspense]      5.847
# 378                 [Fantasía, Acción, Aventura]      7.356
# 436                   [Crimen, Suspense, Acción]      5.500
# 446                     [Comedia, Bélica, Drama]      8.042
# 655                            [Drama, Suspense]      6.688
# 713                   [Acción, Suspense, Terror]      6.700
# 727                             [Drama, Romance]      8.055
# 786                 [Fantasía, Comedia, Romance]      7.536
# 835                                      [Drama]      7.128
# 882                    [Crimen, Drama, Suspense]      7.888
# 938                   [Drama, Fantasía, Romance]      7.775
# 952          [Acción, Comedia, Suspense, Crimen]      6.980
#
#                                                 Poster  \
# 251  https://image.tmdb.org/t/p/w400/2ej8wIzOYBgWQ5...
# 378  https://image.tmdb.org/t/p/w400/uOnutpXJdDWyWz...
# 436  https://image.tmdb.org/t/p/w400/c9FRZfZ3LWMSn6...
# 446  https://image.tmdb.org/t/p/w400/1HZng5VBqkQ1Zd...
# 655  https://image.tmdb.org/t/p/w400/j8wRmze5yJ9uN9...
# 713  https://image.tmdb.org/t/p/w400/5WCuPRfa0h8jMT...
# 727  https://image.tmdb.org/t/p/w400/jtpPxVJkYKCaxV...
# 786  https://image.tmdb.org/t/p/w400/paDvLnSZyrDoUV...
# 835  https://image.tmdb.org/t/p/w400/krdSl7IpDb9c31...
# 882  https://image.tmdb.org/t/p/w400/fpRmDxRLAKCSW3...
# 938  https://image.tmdb.org/t/p/w400/3BUvkcxlIjrZN0...
# 952  https://image.tmdb.org/t/p/w400/u1nopQr6WOxm2u...
#
#                                            Productoras          Pais  \
# 251  [Columbia Pictures, Strike Entertainment, Metr...      [CA, US]
# 378          [Marvel Studios, Kevin Feige Productions]          [US]
# 436  [Universal Pictures, Forward Pass, Legendary P...          [US]
# 446  [Fox Searchlight Pictures, Defender Films, Pik...  [CZ, NZ, US]
# 655  [Le Pacte, Malvalanda, Caballo Films, Movistar...      [FR, ES]
# 713  [Blumhouse Productions, dentsu, White Rabbit P...      [JP, US]
# 727  [Dharma Productions, Fox Searchlight Pictures,...  [IN, AE, US]
# 786  [Pontchartrain Productions, Gravier Production...  [FR, ES, US]
# 835               [Inicia Films, Avalon, Oscilloscope]          [ES]
# 882         [Paul Gregory Productions, United Artists]          [US]
# 938  [Argos Films, Wim Wenders Stiftung, WDR, Road ...      [FR, DE]
# 952  [Prescience, UK Film Council, Reprisal Films, ...          [IE]
#
#     Fecha_Estreno  TMDB_id    IMDB_id  \
# 251    30-01-2014    97020  tt1234721
# 378    04-05-2022   453395  tt9419884
# 436    13-01-2015   201088  tt2717822
# 446    18-10-2019   515001  tt2584384
# 655    11-11-2019   594692  tt9234450
# 713    11-03-2020   514847  tt8244784
# 727    10-02-2010    26022  tt1188996
# 786    11-05-2011    59436  tt1605783
# 835    24-03-2017   438634  tt5897636
# 882    26-08-1955     3112  tt0048424
# 938    17-05-1987      144  tt0093191
# 952    07-07-2011    67913  tt1540133
#
#                                                Reparto  \
# 251  [92404, 64, 2232, 37260, 17183, 39390, 49971, ...
# 378  [71580, 550843, 5294, 30082, 1912381, 1538879,...
# 436  [74568, 38280, 134184, 19492, 7497, 63585, 313...
# 446  [2054851, 1356758, 1245, 55934, 6807, 221581, ...
# 655  [588636, 1919840, 28514, 7276, 9005, 1098350, ...
# 713  [92572, 448, 824, 565501, 198150, 1470, 34847,...
# 727  [35742, 55061, 35792, 1332866, 4115011, 94567,...
# 786  [887, 53714, 29685, 91495, 3968, 971329, 8293,...
# 835  [1440534, 1748696, 1743949, 1149067, 123212, 2...
# 882  [10158, 7632, 8828, 30537, 30538, 9111, 30539,...
# 938  [2310, 2312, 2311, 2313, 2314, 2315, 2317, 122...
# 952  [2039, 1896, 15498, 2983, 549981, 73287, 10417...
#
#                     Director  \
# 251           [José Padilha]
# 378              [Sam Raimi]
# 436           [Michael Mann]
# 446          [Taika Waititi]
# 655      [Rodrigo Sorogoyen]
# 713            [Craig Zobel]
# 727            [Karan Johar]
# 786            [Woody Allen]
# 835            [Carla Simón]
# 882       [Charles Laughton]
# 938            [Wim Wenders]
# 952  [John Michael McDonagh]
#
#                                                  Guion  \
# 251                                   [Joshua Zetumer]
# 378                                                 []
# 436                                                 []
# 446                                    [Taika Waititi]
# 655                   [Rodrigo Sorogoyen, Isabel Peña]
# 713                                                 []
# 727                                  [Shibani Bathija]
# 786                                                 []
# 835                                                 []
# 882                     [James Agee, Charles Laughton]
# 938  [Wim Wenders, Peter Handke, Richard Reitinger,...
# 952                            [John Michael McDonagh]
#
#                                            Video                  Root  \
# 251  https://www.youtube.com/watch?v=8KpSKzT-Fh0  G:\Pelis WD Elements
# 378  https://www.youtube.com/watch?v=JDYdGnpmsgo  G:\Pelis WD Elements
# 436  https://www.youtube.com/watch?v=170Z75vSvec  G:\Pelis WD Elements
# 446  https://www.youtube.com/watch?v=oOnj4i9FKjI  G:\Pelis WD Elements
# 655  https://www.youtube.com/watch?v=HHwIjmFT_Mk                  F:\\
# 713  https://www.youtube.com/watch?v=x8eakp89MEU                  F:\\
# 727  https://www.youtube.com/watch?v=nGH2mTu7AhU                  F:\\
# 786  https://www.youtube.com/watch?v=VHx29JeGjMc                  F:\\
# 835  https://www.youtube.com/watch?v=SHWIyaqfenA                  F:\\
# 882  https://www.youtube.com/watch?v=oWqWmmiTOBI                  F:\\
# 938  https://www.youtube.com/watch?v=0pwgFOCBaOw                  F:\\
# 952  https://www.youtube.com/watch?v=iJxBKglv2zw                  F:\\
#
#                    Folder                                               File  \
# 251          Robocop 2014  Robocop.(2014).(Spanish.English.Subs).HD.1080p...
# 378             0_ULTIMAS  Doctor.Strange.In.The.Multiverse.Of.Madness.(2...
# 436             0_ULTIMAS  Blackhat..Amenaza.en.la.red.(2015).(Spanish.En...
# 446             0_ULTIMAS  Jojo Rabbit (Spanish English Subs) Hd 1080p X2...
# 655              A_NUEVAS  Madre.(2019).(Spanish).WEB-DL.1080p.HEVC.10b-A...
# 713              A_NUEVAS  La.caza.(2020).(Spanish.English.Spanishsub).BD...
# 727     Mi nombre es kahn  Mi.nombre.es.Khan.(parte1).(Spanish.Hindi).HDr...
# 786     Midnight in Paris  Midnight.in.Paris.2011.(Spanish.English).HDrip...
# 835              A_NUEVAS  Verano.1993.(Carla.SimÓn,2017).(Spanish).DVD-R...
# 882  La noche del cazador  La.Noche.Del.Cazador.(Spanish.English).HDrip.X...
# 938              A_NUEVAS  El.cielo.sobre.Berlín.(1987).(Spanish.German.S...
# 952           El Irlandés  El.Irlandes.(The.Guard)(2011).(Spanish.French)...
#
#      Vista         Add
# 251   True  27-09-2023
# 378   True  03-10-2023
# 436   True  03-10-2023
# 446   True  03-10-2023
# 655  False  09-10-2023
# 713  False  09-10-2023
# 727  False  09-10-2023
# 786  False  09-10-2023
# 835  False  09-10-2023
# 882  False  09-10-2023
# 938  False  09-10-2023
# 952  False  09-10-2023

# %%
films.loc[106,'Titulo']
# Out:
# 'La caza'

# %%
films = films.drop(index=[165]).reset_index(drop=True)

# %%
films.loc[159,'Root'] = 'G:\Pelis WD Elements'
films.loc[159,'Folder'] = 'Guardianes de la galaxia'

# %%
films.to_parquet('films.parquet',engine='pyarrow')

# %% [markdown]
# ## Actualizar films

# %%
scan = pd.read_parquet('scan.parquet')
df = scan[scan.API_pass == False]

save_data(df)
scan = pd.read_parquet('scan.parquet')
scan[scan.API_pass == False]
# Out:
#                           Titulo  Year  Root                 Folder  \
# 1028          La Ultima Estacion        F:\\     La ultima estacion
# 1058  Indomable - Haywire [2011]  2011  F:\\              Indomable
# 1072              Anonymous 2011  2011  F:\\              Anonymous
# 1081  Muerte de un ciclista 1955  1955  F:\\  Muerte de un ciclista
# 1085            John Carter 2012  2012  F:\\            John Carter
#
#                                                    File  API_pass
# 1028  La.Ultima.Estacion.(The.Last.Station).(Spanish...     False
# 1058  Indomable.-.Haywire.[2011].(Catala.Spanish..En...     False
# 1072  Anonymous.2011.(Spanish.English).HDrip.XviD-AC...     False
# 1081  Muerte.de.un.ciclista.1955.(Spanish.Subs).BDri...     False
# 1085  John.Carter.2012.(Spanish.English).HDrip.XviD-...     False

# %%
insert_data(1085,49529)
films = pd.read_parquet('films.parquet')
films.tail(2)
# Out:
#                      Titulo        Titulo_Original  Year  Duracion  \
# 1070  Muerte de un ciclista  Muerte de un ciclista  1955        90
# 1071            John Carter            John Carter  2012       132
#
#                    Tag_Line  \
# 1070    Muerte en el camino
# 1071  Dos mundos. Un héroe.
#
#                                                Sinopsis  \
# 1070  Un profesor de universidad y su amante, una mu...
# 1071  Adaptación de ‘Una princesa de Marte’, la prim...
#
#                                    Genero  TMDB_rate  \
# 1070            [Crimen, Drama, Suspense]      7.144
# 1071  [Acción, Aventura, Ciencia ficción]      6.298
#
#                                                  Poster  \
# 1070  https://image.tmdb.org/t/p/w400/otJYYj4si0Kwab...
# 1071  https://image.tmdb.org/t/p/w400/lRvQP1wLqyPJEg...
#
#                                      Productoras      Pais Fecha_Estreno  \
# 1070  [Guión PC, Trionfalcine, Cesáreo González]  [ES, IT]    07-09-1955
# 1071                      [Walt Disney Pictures]      [US]    07-03-2012
#
#       TMDB_id    IMDB_id                                            Reparto  \
# 1070    72083  tt0048394  [39274, 240197, 132481, 89776, 1048709, 104884...
# 1071    49529  tt0401729  [60900, 21044, 2206, 5293, 19159, 2983, 8785, ...
#
#                    Director                                           Guion  \
# 1070  [Juan Antonio Bardem]    [Juan Antonio Bardem, Luis Fernando de Igoa]
# 1071       [Andrew Stanton]  [Andrew Stanton, Michael Chabon, Mark Andrews]
#
#                                             Video  Root  \
# 1070                                               F:\\
# 1071  https://www.youtube.com/watch?v=12MKMj86078  F:\\
#
#                      Folder  \
# 1070  Muerte de un ciclista
# 1071            John Carter
#
#                                                    File  Vista         Add
# 1070  Muerte.de.un.ciclista.1955.(Spanish.Subs).BDri...  False  09-10-2023
# 1071  John.Carter.2012.(Spanish.English).HDrip.XviD-...  False  09-10-2023

# %%
scan = pd.read_parquet('scan.parquet')

dictio = get_data(385687)
dictio['Root'] = scan.loc[31, 'Root']
dictio['Folder'] = scan.loc[31, 'Folder']
dictio['File'] = scan.loc[31, 'File']
dictio['Vista'] = False
dictio['Add'] = datetime.today().date().strftime('%d-%m-%Y')

pd.DataFrame([dictio])
# Out:
#              Titulo Titulo_Original  Year  Duracion  \
# 0  Fast & Furious X          Fast X  2023       142
#
#                         Tag_Line  \
# 0  El final del camino comienza.
#
#                                             Sinopsis  \
# 0  Dom Toretto y su familia se convierten en el o...
#
#                        Genero  TMDB_rate  \
# 0  [Acción, Crimen, Suspense]      7.262
#
#                                               Poster  \
# 0  https://image.tmdb.org/t/p/w400/3P9QvWVN02Etn4...
#
#                                          Productoras  Pais Fecha_Estreno  \
# 0  [Universal Pictures, Original Film, One Race, ...  [US]    17-05-2023
#
#    TMDB_id    IMDB_id                                            Reparto  \
# 0   385687  tt5433140  [12835, 17647, 8169, 8171, 56446, 1251069, 221...
#
#             Director                     Guion  \
# 0  [Louis Leterrier]  [Justin Lin, Dan Mazeau]
#
#                                          Video      Root Folder  \
# 0  https://www.youtube.com/watch?v=cg5z7wgOUig  E:\Emule
#
#                                                 File  Vista         Add
# 0  Fast.and.Furious.-.A.todo.gas.10.(2023).(Spani...  False  26-09-2023

# %% [markdown]
# ## Corrección scan

# %%
scan = pd.read_parquet('scan.parquet')
scan.tail(2)
# Out:
#              Titulo Year  Root          Folder  \
# 1108       La trama       F:\\        La Trama
# 1109  Adventureland       F:\\  Adeventureland
#
#                                                    File  API_pass
# 1108  La.trama.(English.Subs).DVD-Rip.XviD-AC3.by.Ka...      True
# 1109  Adventureland.(Spanish.English).HDrip.XviD-AC3...      True

# %%
scan[scan.API_pass == False].head(10)
# Out:
# Empty DataFrame
# Columns: [Titulo, Year, Root, Folder, File, API_pass]
# Index: []

# %%
scan[scan.Titulo.str.contains('Cruce')]
# Out:
#                 Titulo  Year  Root            Folder  \
# 831   Cruce de caminos        F:\\  Cruce de caminos
# 1056  Cruce de Caminos  2012  F:\\  Cruce de caminos
#
#                                                    File  API_pass
# 831   Cruce.de.caminos.(English.Spanishsub.Englishsu...      True
# 1056  Cruce.de.Caminos.(2012).(Spanish.English.Subs)...     False

# %%
scan.loc[[944],'API_pass'] = True

# %%
scan.loc[646]
# Out:
# Titulo                                        La conspiracion
# Year
# Root                                                     F:\\
# Folder                                        La Conspiración
# File        La.conspiracion.(Spanish.English).HDrip.XviD-A...
# API_pass                                                 True
# Name: 646, dtype: object

# %%
scan.to_parquet('scan.parquet', engine='pyarrow')

# %%
scan.loc[]

# %% [markdown]
# ## Eliminar registro film

# %%
delete_film(831)

# %% [markdown]
# ## Actualizar scan

# %%
insert_scan(FOLDER[2])
