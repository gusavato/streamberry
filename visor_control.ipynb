# %%
from api import *
from folder import *
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Solve Data

# %%
index = 14
solve_data(index)
films = pd.read_parquet('films.parquet')
films.loc[index,:]
# Out:
# Titulo                                        Camera Cafe: The Movie
# Titulo_Original                             Camera café: la película
# Year                                                            2022
# Duracion                                                          90
# Tag_Line
# Sinopsis           Jesús Quesada, an incompetent executive, is ap...
# Genero                                                      [Comedy]
# TMDB_rate                                                      5.449
# Poster             https://image.tmdb.org/t/p/w400/wlHZV96gSY5UOm...
# Productoras        [Pólvora Films, Estela Films, LACOproductora, ...
# Pais                                                        [PT, ES]
# Fecha_Estreno                                             25-03-2022
# TMDB_id                                                       762823
# IMDB_id                                                   tt12089564
# Reparto            [1042765, 1068844, 1170019, 1023515, 111090, 1...
# Director                                           [Ernesto Sevilla]
# Guion               [Joaquín Reyes, Ernesto Sevilla, Miguel Esteban]
# Video
# Root                                                            None
# Folder             Camera.Café,.la.película.(2022).(Spanish).WEB-...
# File               Camera.Café,.la.película.(2022).(Spanish).WEB-...
# Vista                                                          False
# Add                                                       26-09-2023
# Name: 14, dtype: object

# %%
index = 224      
TMDB_id = 10523

solve_data(index, TMDB_id)
films = pd.read_parquet('films.parquet')
films.loc[index,:]
# Out:
# Titulo                                                            W.
# Titulo_Original                                                   W.
# Year                                                            2008
# Duracion                                                         129
# Tag_Line
# Sinopsis           Biografía de George W. Bush (Josh Brolin) que ...
# Genero                                             [Drama, Historia]
# TMDB_rate                                                      6.269
# Poster             https://image.tmdb.org/t/p/w400/nJm8UF4zbUYEok...
# Productoras        [Ixtlan Productions, JCE Movies, Global Entert...
# Pais                                                            [US]
# Fecha_Estreno                                             17-10-2008
# TMDB_id                                                        10523
# IMDB_id                                                    tt1175491
# Reparto             [16851, 9281, 9560, 2505, 3037, 349, 13014, 825]
# Director                                              [Oliver Stone]
# Guion                                                             []
# Video                    https://www.youtube.com/watch?v=ZdJd5y3mHEU
# Root                                            G:\Pelis WD Elements
# Folder                                                             W
# File               W.(Spanish.English).DVD-Rip.XviD-AC3.(by.ZonaR...
# Vista                                                          False
# Add                                                       27-09-2023
# Name: 224, dtype: object

# %% [markdown]
# ## Explorar films

# %%
films = pd.read_parquet('films.parquet')
films.head(2)
# Out:
#                                 Titulo  \
# 0  Ninja Turtles: Fuera de las sombras
# 1     Ant-Man y la Avispa: Quantumanía
#
#                                     Titulo_Original  Year  Duracion  \
# 0  Teenage Mutant Ninja Turtles: Out of the Shadows  2016       112
# 1                 Ant-Man and the Wasp: Quantumania  2023       125
#
#                                          Tag_Line  \
# 0       Sólo un equipo puede defendernos a todos.
# 1  Sé testigo del comienzo de una nueva dinastía.
#
#                                             Sinopsis  \
# 0  Michelangelo, Donatello, Leonardo y Raphael re...
# 1  La pareja de superhéroes Scott Lang y Hope van...
#
#                                               Genero  TMDB_rate  \
# 0  [Acción, Aventura, Comedia, Familia, Ciencia f...      6.007
# 1                [Acción, Aventura, Ciencia ficción]      6.436
#
#                                               Poster  \
# 0  https://image.tmdb.org/t/p/w400/t24yGNL0aLFFfN...
# 1  https://image.tmdb.org/t/p/w400/lKHy0ntGPdQeFw...
#
#                                          Productoras  Pais Fecha_Estreno  \
# 0  [5150 Action, Paramount, Nickelodeon Movies, P...  [US]    01-06-2016
# 1          [Marvel Studios, Kevin Feige Productions]  [US]    15-02-2023
#
#    TMDB_id     IMDB_id                                            Reparto  \
# 0   308531   tt3949660  [19537, 350, 21200, 76110, 1163622, 64295, 803...
# 1   640146  tt10954600  [22226, 19034, 1674162, 221192, 1160, 3392, 74...
#
#         Director                          Guion  \
# 0   [Dave Green]  [Josh Appelbaum, André Nemec]
# 1  [Peyton Reed]                             []
#
#                                          Video      Root Folder  \
# 0  https://www.youtube.com/watch?v=Zvr3WvcYEeI  E:\Emule
# 1  https://www.youtube.com/watch?v=vbcAD04DWFE  E:\Emule
#
#                                                 File  Vista         Add
# 0  Teenage.Mutant.Ninja.Turtles.Out.of.the.Shadow...  False  26-09-2023
# 1  Ant-Man.Y.La.Avispa.(Quantumania).(Spanish.Eng...  False  26-09-2023

# %%
films[films.Titulo.str.contains('tercer')]
# Out:
#                Titulo Titulo_Original  Year  Duracion  \
# 247  El tercer hombre   The Third Man  1949       104
#
#                                         Tag_Line  \
# 247  Cazado por hombres ... Buscado por MUJERES!
#
#                                               Sinopsis                Genero  \
# 247  Orson Welles es Harry Lime y Joseph Cotten act...  [Suspense, Misterio]
#
#      TMDB_rate                                             Poster  \
# 247      7.949  https://image.tmdb.org/t/p/w400/trsJPVYVnZMPhB...
#
#                                         Productoras  Pais Fecha_Estreno  \
# 247  [London Films Productions, British Lion Films]  [GB]    31-08-1949
#
#      TMDB_id    IMDB_id                                            Reparto  \
# 247     1092  tt0041959  [7664, 15385, 40, 12726, 14120, 29177, 13376, ...
#
#          Director            Guion  \
# 247  [Carol Reed]  [Graham Greene]
#
#                                            Video                  Root  \
# 247  https://www.youtube.com/watch?v=gVTFD2t0klw  G:\Pelis WD Elements
#
#                Folder                                               File  \
# 247  El Tercer Hombre  El.tercer.hombre.[1949].(Spanish.English..Span...
#
#      Vista         Add
# 247   True  27-09-2023

# %%
films.tail()
# Out:
#                Titulo    Titulo_Original  Year  Duracion  \
# 262              Dune               Dune  2021       155
# 263     Adiós pequeña      Adiós pequeña  1986        89
# 264      Nightcrawler       Nightcrawler  2014       117
# 265  Los odiosos ocho  The Hateful Eight  2015       187
# 266    Shutter Island     Shutter Island  2010       138
#
#                                           Tag_Line  \
# 262         Más allá del miedo, el destino espera.
# 263
# 264           La cuidad es mas brillante de noche.
# 265  Nadie viene hasta aquí sin una maldita razón.
# 266                         El miedo es contagioso
#
#                                               Sinopsis  \
# 262  En un lejano futuro, la galaxia conocida es go...
# 263  Beatriz es una joven y atractiva abogada que d...
# 264  Un joven descubre el mundo del periodismo free...
# 265  Seis, ocho o doce años después de la Guerra de...
# 266  Verano de 1954. Los agentes judiciales Teddy D...
#
#                           Genero  TMDB_rate  \
# 262  [Ciencia ficción, Aventura]      7.788
# 263                   [Suspense]      0.000
# 264    [Crimen, Drama, Suspense]      7.703
# 265   [Drama, Misterio, Western]      7.747
# 266  [Drama, Suspense, Misterio]      8.200
#
#                                                 Poster  \
# 262  https://image.tmdb.org/t/p/w400/qf5bntGx2p5kQK...
# 263  https://image.tmdb.org/t/p/w400/nFu4c4sCvK00uj...
# 264  https://image.tmdb.org/t/p/w400/mP9JaSGi81tU1a...
# 265  https://image.tmdb.org/t/p/w400/7DYGdFT4gtiD5B...
# 266  https://image.tmdb.org/t/p/w400/56utveUWJwmG12...
#
#                                            Productoras  Pais Fecha_Estreno  \
# 262                               [Legendary Pictures]  [US]    15-09-2021
# 263                                 [Travelling Films]  [ES]    31-10-1986
# 264                      [Sierra/Affinity, Bold Films]  [US]    23-10-2014
# 265  [The Weinstein Company, Double Feature Films, ...  [US]    25-12-2015
# 266  [Phoenix Pictures, Paramount, Appian Way, Sike...  [US]    14-02-2010
#
#      TMDB_id    IMDB_id                                            Reparto  \
# 262   438631  tt1160419  [1190668, 933238, 25072, 16851, 1640, 543530, ...
# 263   121777  tt0090591  [227395, 21181, 15184, 36277, 30358, 34795, 78...
# 264   242582  tt2872718  [131, 14343, 53240, 2053, 97604, 61084, 36060,...
# 265   273248  tt3460252  [2231, 6856, 10431, 27740, 76961, 3129, 147, 6...
# 266    11324  tt1130884   [6193, 103, 2282, 1812, 1246, 1276, 2201, 17183]
#
#                 Director                                       Guion  \
# 262   [Denis Villeneuve]  [Eric Roth, Denis Villeneuve, Jon Spaihts]
# 263       [Imanol Uribe]                                          []
# 264         [Dan Gilroy]                                          []
# 265  [Quentin Tarantino]                         [Quentin Tarantino]
# 266    [Martin Scorsese]                          [Laeta Kalogridis]
#
#                                            Video                  Root  \
# 262  https://www.youtube.com/watch?v=kPjOcWHVNGo  G:\Pelis WD Elements
# 263                                               G:\Pelis WD Elements
# 264  https://www.youtube.com/watch?v=7uaYhPpV7G4  G:\Pelis WD Elements
# 265  https://www.youtube.com/watch?v=IMGwqSA9rww  G:\Pelis WD Elements
# 266  https://www.youtube.com/watch?v=vmvDCDC9Ylc  G:\Pelis WD Elements
#
#                    Folder                                               File  \
# 262             0_ULTIMAS  Dune.(2021).(Spanish.English.Spanishsub.Englis...
# 263  Adiós pequeña, adiós  Adios.Pequena.Adios.(Spanish.English).DVD-Rip....
# 264          Nightcrawler  Nightcrawler.(Spanish.English.spanishsub.engli...
# 265      Los Odiosos Ocho  Los.odiosos.ocho.(Spanish.English.spanishsub.e...
# 266        Shutter island  Shutter.Island.(parte1).(Spanish.English).HDri...
#
#      Vista         Add
# 262   True  03-10-2023
# 263  False  03-10-2023
# 264  False  03-10-2023
# 265  False  03-10-2023
# 266  False  03-10-2023

# %%
films = films.drop(index=[265,267,269]).reset_index(drop=True)

# %%
films.loc[159,'Root'] = 'G:\Pelis WD Elements'
films.loc[159,'Folder'] = 'Guardianes de la galaxia'

# %%
films.to_parquet('films.parquet',engine='pyarrow')

# %% [markdown]
# ## Actualizar films

# %%
scan = pd.read_parquet('scan.parquet')
df = scan[scan.API_pass == False][:1]

save_data(df)
scan = pd.read_parquet('scan.parquet')
scan[scan.API_pass == False].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\augus\PYTHON\streamberry\visor_control.ipynb Celda 11 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/augus/PYTHON/streamberry/visor_control.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> scan = pd.read_parquet('scan.parquet')
#       <a href='vscode-notebook-cell:/c%3A/Users/augus/PYTHON/streamberry/visor_control.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> df = scan[scan.API_pass == False][:1]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/augus/PYTHON/streamberry/visor_control.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> save_data(df)
#       <a href='vscode-notebook-cell:/c%3A/Users/augus/PYTHON/streamberry/visor_control.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> scan = pd.read_parquet('scan.parquet')
#       <a href='vscode-notebook-cell:/c%3A/Users/augus/PYTHON/streamberry/visor_control.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> scan[scan.API_pass == False].head(10)
#
# File c:\Users\augus\PYTHON\streamberry\api.py:162, in save_data(df)
#     160 except:
#     161     continue
# --> 162 dictio = get_data(TMDB_id)
#     163 dictio['Root'] = i[3]
#     164 dictio['Folder'] = i[4]
#
# File c:\Users\augus\PYTHON\streamberry\api.py:141, in get_data(TMDB_id)
#     136 """
#     137 Función que une toda la información extraida de la API
#     138 """
#     140 dictio = get_details(TMDB_id)
# --> 141 dictio['Reparto'] = get_cast(TMDB_id)['Id'].to_list()
#     142 dictio = {**dictio, **get_director_writer(TMDB_id)}
#     143 dictio['Video'] = get_video(TMDB_id)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
# --> 418     raise KeyError(key)
#     419 self._check_indexing_error(key)
#     420 raise KeyError(key)
#
# KeyError: 'Id'

# %%
insert_data(246,1092)
films = pd.read_parquet('films.parquet')
films.tail(2)
# Out:
#                Titulo Titulo_Original  Year  Duracion  \
# 268    Shutter Island  Shutter Island  2010       138
# 269  El tercer hombre   The Third Man  1949       104
#
#                                         Tag_Line  \
# 268                       El miedo es contagioso
# 269  Cazado por hombres ... Buscado por MUJERES!
#
#                                               Sinopsis  \
# 268  Verano de 1954. Los agentes judiciales Teddy D...
# 269  Orson Welles es Harry Lime y Joseph Cotten act...
#
#                           Genero  TMDB_rate  \
# 268  [Drama, Suspense, Misterio]        8.2
# 269         [Suspense, Misterio]        7.9
#
#                                                 Poster  \
# 268  https://image.tmdb.org/t/p/w400/56utveUWJwmG12...
# 269  https://image.tmdb.org/t/p/w400/trsJPVYVnZMPhB...
#
#                                            Productoras  Pais Fecha_Estreno  \
# 268  [Phoenix Pictures, Paramount, Appian Way, Sike...  [US]    14-02-2010
# 269     [London Films Productions, British Lion Films]  [GB]    31-08-1949
#
#      TMDB_id    IMDB_id                                            Reparto  \
# 268    11324  tt1130884   [6193, 103, 2282, 1812, 1246, 1276, 2201, 17183]
# 269     1092  tt0041959  [7664, 15385, 40, 12726, 14120, 29177, 13376, ...
#
#               Director               Guion  \
# 268  [Martin Scorsese]  [Laeta Kalogridis]
# 269       [Carol Reed]     [Graham Greene]
#
#                                            Video                  Root  \
# 268  https://www.youtube.com/watch?v=vmvDCDC9Ylc  G:\Pelis WD Elements
# 269  https://www.youtube.com/watch?v=gVTFD2t0klw  G:\Pelis WD Elements
#
#                Folder                                               File  \
# 268    Shutter island  Shutter.Island.(parte1).(Spanish.English).HDri...
# 269  El Tercer Hombre  El.tercer.hombre.[1949].(Spanish.English..Span...
#
#      Vista         Add
# 268  False  03-10-2023
# 269  False  03-10-2023

# %%
scan = pd.read_parquet('scan.parquet')

dictio = get_data(385687)
dictio['Root'] = scan.loc[31, 'Root']
dictio['Folder'] = scan.loc[31, 'Folder']
dictio['File'] = scan.loc[31, 'File']
dictio['Vista'] = False
dictio['Add'] = datetime.today().date().strftime('%d-%m-%Y')

pd.DataFrame([dictio])
# Out:
#              Titulo Titulo_Original  Year  Duracion  \
# 0  Fast & Furious X          Fast X  2023       142
#
#                         Tag_Line  \
# 0  El final del camino comienza.
#
#                                             Sinopsis  \
# 0  Dom Toretto y su familia se convierten en el o...
#
#                        Genero  TMDB_rate  \
# 0  [Acción, Crimen, Suspense]      7.262
#
#                                               Poster  \
# 0  https://image.tmdb.org/t/p/w400/3P9QvWVN02Etn4...
#
#                                          Productoras  Pais Fecha_Estreno  \
# 0  [Universal Pictures, Original Film, One Race, ...  [US]    17-05-2023
#
#    TMDB_id    IMDB_id                                            Reparto  \
# 0   385687  tt5433140  [12835, 17647, 8169, 8171, 56446, 1251069, 221...
#
#             Director                     Guion  \
# 0  [Louis Leterrier]  [Justin Lin, Dan Mazeau]
#
#                                          Video      Root Folder  \
# 0  https://www.youtube.com/watch?v=cg5z7wgOUig  E:\Emule
#
#                                                 File  Vista         Add
# 0  Fast.and.Furious.-.A.todo.gas.10.(2023).(Spani...  False  26-09-2023

# %% [markdown]
# ## Corrección scan

# %%
scan = pd.read_parquet('scan.parquet')
scan.tail(2)
# Out:
#                      Titulo Year                  Root  \
# 589  El instante mas oscuro       G:\Pelis WD Elements
# 590               Midsommar       G:\Pelis WD Elements
#
#                      Folder  \
# 589  El instante más oscuro
# 590               0_ULTIMAS
#
#                                                   File  API_pass
# 589  El.instante.mas.oscuro.(Spanish.English..Subs)...     False
# 590  Midsommar.(Spanish.English.Subs).HD.1080p.x264...     False

# %%
scan.loc[[229,243],'API_pass'] = True

# %%
scan[scan.API_pass == False][:30]
# Out:
#                           Titulo  Year                  Root  \
# 246      El tercer hombre [1949]  1949  G:\Pelis WD Elements
# 255   Malos Tiempos En El Royale        G:\Pelis WD Elements
# 256                  Zoolander 2        G:\Pelis WD Elements
# 257               Gangster Squad        G:\Pelis WD Elements
# 258              Synth Britannia  2009  G:\Pelis WD Elements
# 259                 El mayordomo  2013  G:\Pelis WD Elements
# 260                        Equus  1977  G:\Pelis WD Elements
# 261                      Robocop  2014  G:\Pelis WD Elements
# 262                       Mongol        G:\Pelis WD Elements
# 263                  Snowpiercer        G:\Pelis WD Elements
# 264    Homicidio en primer grado  1995  G:\Pelis WD Elements
# 265                         Argo  2012  G:\Pelis WD Elements
# 266           A Day at the Races  1937  G:\Pelis WD Elements
# 267                  El escritor  2010  G:\Pelis WD Elements
# 268           Cuatro Fantasticos  2015  G:\Pelis WD Elements
# 269                         Dune  2021  G:\Pelis WD Elements
# 270          Adios Pequena Adios        G:\Pelis WD Elements
# 271                 Nightcrawler        G:\Pelis WD Elements
# 272             Los odiosos ocho        G:\Pelis WD Elements
# 273               Shutter Island        G:\Pelis WD Elements
# 274         El ultimo gran heroe        G:\Pelis WD Elements
# 275                Desafio total  1990  G:\Pelis WD Elements
# 276      Mientras dure la Guerra  2019  G:\Pelis WD Elements
# 277  La guerra de Charlie Wilson        G:\Pelis WD Elements
# 278                   Mr  Nobody        G:\Pelis WD Elements
# 279               Tortugas Ninja  1990  G:\Pelis WD Elements
# 280               Es por tu bien        G:\Pelis WD Elements
# 281               Doctor Strange        G:\Pelis WD Elements
# 282                   El cazador        G:\Pelis WD Elements
# 283   El hombre de las mil caras        G:\Pelis WD Elements
#
#                                   Folder  \
# 246                     El Tercer Hombre
# 255           Malos tiempos en el Royale
# 256                          Zoolander 2
# 257                       Gangster Squad
# 258                      Synth Britannia
# 259                         El Mayordomo
# 260                                Equus
# 261                         Robocop 2014
# 262                               Mongol
# 263                          Snowpiercer
# 264            Homicidio en primer grado
# 265                                 Argo
# 266  Hermanos MarxUn día en las carreras
# 267                          El escritor
# 268                   Cuatro Fantásticos
# 269                            0_ULTIMAS
# 270                 Adiós pequeña, adiós
# 271                         Nightcrawler
# 272                     Los Odiosos Ocho
# 273                       Shutter island
# 274                 El último gran héroe
# 275                        Desafío total
# 276              Mientras dure la guerra
# 277          La guerra de Charlie Wilson
# 278                           Mr. Nobody
# 279                   Las tortugas ninja
# 280                       Es por tu bien
# 281                          Dr. Extraño
# 282                           El cazador
# 283           El hombre de las mil caras
#
#                                                   File  API_pass
# 246  El.tercer.hombre.[1949].(Spanish.English..Span...     False
# 255  Malos.Tiempos.En.El.Royale.(Spanish.English.Su...     False
# 256  Zoolander.2.(English..SpanishSub).HDrip.XviD-A...     False
# 257  Gangster.Squad.(English.Subs).DVD-Rip.XviD-AC3...     False
# 258  Synth.Britannia.(2009).(English.Subs).TDT-Rip....     False
# 259  El.mayordomo.(The.Butler.2013).(Spanish.Englis...     False
# 260  Equus.(Sidney.Lumet,.1977).(Spanish.English.Su...     False
# 261  Robocop.(2014).(Spanish.English.Subs).HD.1080p...     False
# 262  Mongol.(Spanish.Mongolian).DVD-Rip.XviD-AC3-mp...     False
# 263  Snowpiercer.(Rompenieves).(Spanish.English.Spa...     False
# 264  Homicidio.en.primer.grado.(Murder.in.the.first...     False
# 265  Argo.(2012).(Spanish.English.Subs).BDrip.1080p...     False
# 266  A.Day.at.the.Races.(Sam.Wood,.1937).(Spanish.E...     False
# 267  El.escritor.(2010).(Spanish.English.Subs).HDri...     False
# 268  Cuatro.Fantasticos.(2015).(Spanish.English.Spa...     False
# 269  Dune.(2021).(Spanish.English.Spanishsub.Englis...     False
# 270  Adios.Pequena.Adios.(Spanish.English).DVD-Rip....     False
# 271  Nightcrawler.(Spanish.English.spanishsub.engli...     False
# 272  Los.odiosos.ocho.(Spanish.English.spanishsub.e...     False
# 273  Shutter.Island.(parte1).(Spanish.English).HDri...     False
# 274  El.ultimo.gran.heroe.(Spanish.English).HDrip.X...     False
# 275  Desafio.total.(Paul.Verhoeven,1990).(Spanish.E...     False
# 276                 Mientras dure la Guerra (2019).avi     False
# 277  La.guerra.de.Charlie.Wilson.(Spanish.English.S...     False
# 278  Mr..Nobody.(Parte.1).(Spanish.English).HDrip.X...     False
# 279  Tortugas.Ninja.(1990).(Spanish.English).HDrip....     False
# 280  Es.por.tu.bien.(Spanish).BDrip.1080p.x264-AC3....     False
# 281  Doctor.Strange.(Spanish.English.Subs).HD.1080p...     False
# 282  El.cazador.(Spanish.English).HDrip.XviD-AC3.by...     False
# 283  El.hombre.de.las.mil.caras.(Spanish).BDrip.m10...     False

# %%
# scan.to_parquet('scan.parquet', engine='pyarrow')

# %%
scan[scan.Titulo.str.contains('Futuro')]
# Out:
#                            Titulo  Year                  Root  \
# 126         Regreso Al Futuro III        G:\Pelis WD Elements
# 153  X Men Dias Del Futuro Pasado  2014  G:\Pelis WD Elements
# 184             Regreso Al Futuro        G:\Pelis WD Elements
# 435          Regreso Al Futuro II        G:\Pelis WD Elements
#
#                             Folder  \
# 126                      0_ULTIMAS
# 153  X-Men. Días del futuro pasado
# 184                      0_ULTIMAS
# 435                      0_ULTIMAS
#
#                                                   File  API_pass
# 126  Regreso.Al.Futuro.III.(Spanish.English.Subs).U...      True
# 153  X.Men.Dias.Del.Futuro.Pasado.(2014).(Spanish.E...      True
# 184  Regreso.Al.Futuro.(Spanish.English.Subs).UHD.1...      True
# 435  Regreso.Al.Futuro.II.(Spanish.English.Subs).UH...     False

# %%
scan.loc[]

# %% [markdown]
# ## Eliminar registro film

# %%
delete_film(142)
